# %%
import matplotlib
import pandas as pd

# %%
treatment_subject_csv = pd.read_csv('./treatment _subject20206.csv',encoding='euc-kr')
treatment_subject_csv.head()
# Out:
#                                           암호화YKIHO코드           요양기관명  진료과목코드  \
# 0  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...  가톨릭대학교 여의도성모병원       1
# 1  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQyIy...    한림대학교 강남성심병원       1
# 2  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...    한림대학교 한강성심병원       1
# 3  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...         중앙대학교병원       1
# 4  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...      서울특별시보라매병원       1
#
#   진료과목코드명  과목별 전문의수  선택진료 의사수
# 0      내과        37         0
# 1      내과        35         0
# 2      내과         2         0
# 3      내과        58         0
# 4      내과        63         0

# %%
dental_treatment_subject = treatment_subject_csv['진료과목코드'].isin([49,50,51,52,54,55,56,57,58,61])==True
dental_treatment_subject = treatment_subject_csv[dental_treatment_subject]

# %%
dental_treatment_subject.head()
# Out:
#                                                암호화YKIHO코드        요양기관명  \
# 151447  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...       삼육서울병원
# 151448  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...  인제대학교 서울백병원
# 151449  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...   서울특별시보라매병원
# 151450  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...      서울대학교병원
# 151451  JDQ4MTg4MSM1MSMkMSMkMCMkODkkMzgxMzUxIzExIyQxIy...   서울특별시 동부병원
#
#         진료과목코드 진료과목코드명  과목별 전문의수  선택진료 의사수
# 151447      49      치과         0         0
# 151448      49      치과         0         0
# 151449      49      치과         0         0
# 151450      49      치과         0         0
# 151451      49      치과         0         0

# %%
grouping=dental_treatment_subject.groupby(['요양기관명','진료과목코드명'], as_index=False)

# %%
dental_treatment_subject[dental_treatment_subject['요양기관명']=='강충희치과의원']
# Out:
#                                                암호화YKIHO코드    요양기관명  진료과목코드  \
# 163219  JDQ4MTg4MSM1MSMkMSMkMCMkNzIkMzgxNzAyIzQxIyQxIy...  강충희치과의원      50
# 177384  JDQ4MTg4MSM1MSMkMSMkMCMkNzIkMzgxNzAyIzQxIyQxIy...  강충희치과의원      51
# 177433  JDQ4MTg4MSM1MSMkMSMkMCMkNzIkMzgxNzAyIzQxIyQxIy...  강충희치과의원      52
# 190615  JDQ4MTg4MSM1MSMkMSMkMCMkNzIkMzgxNzAyIzQxIyQxIy...  강충희치과의원      54
# 204636  JDQ4MTg4MSM1MSMkMSMkMCMkNzIkMzgxNzAyIzQxIyQxIy...  강충희치과의원      55
# 204651  JDQ4MTg4MSM1MSMkMSMkMCMkNzIkMzgxNzAyIzQxIyQxIy...  강충희치과의원      56
# 216429  JDQ4MTg4MSM1MSMkMSMkMCMkNzIkMzgxNzAyIzQxIyQxIy...  강충희치과의원      57
# 216498  JDQ4MTg4MSM1MSMkMSMkMCMkNzIkMzgxNzAyIzQxIyQxIy...  강충희치과의원      58
#
#         진료과목코드명  과목별 전문의수  선택진료 의사수
# 163219  구강악안면외과         0         0
# 177384    치과보철과         0         0
# 177433    치과교정과         0         0
# 190615      치주과         0         0
# 204636    치과보존과         0         0
# 204651     구강내과         0         0
# ...

# %%
dental_treatment_subject.to_json('dental_treatment_subject.json', orient='records')
