# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon, LineString
import matplotlib
import pandas as pd
print (plt.rcParams['font.size'] ) 
print (plt.rcParams['font.family'] )
# Out:
# 10.0
# ['sans-serif']

# %%
emd_area = gpd.GeoDataFrame.from_file('./EMD_202005/EMD.shp', encoding='cp949')
emd_area.head()
# Out:
#      EMD_CD       EMD_ENG_NM EMD_KOR_NM  \
# 0  11110101    Cheongun-dong        청운동
# 1  11110102      Singyo-dong        신교동
# 2  11110103   Gungjeong-dong        궁정동
# 3  11110104       Hyoja-dong        효자동
# 4  11110105  Changseong-dong        창성동
#
#                                             geometry
# 0  POLYGON ((953700.022 1954605.065, 953693.871 1...
# 1  POLYGON ((953233.465 1953996.984, 953235.183 1...
# 2  POLYGON ((953560.228 1954257.466, 953561.190 1...
# 3  POLYGON ((953519.843 1953890.785, 953518.489 1...
# 4  POLYGON ((953516.123 1953734.362, 953516.526 1...

# %%
ctprvn_area = gpd.GeoDataFrame.from_file('./CTPRVN_202005/CTPRVN.shp', encoding='cp949')
ctprvn_area.head()
# Out:
#   CTPRVN_CD CTP_ENG_NM CTP_KOR_NM  \
# 0        11      Seoul      서울특별시
# 1        26      Busan      부산광역시
# 2        27      Daegu      대구광역시
# 3        28    Incheon      인천광역시
# 4        29    Gwangju      광주광역시
#
#                                             geometry
# 0  POLYGON ((966987.226 1941110.946, 966987.119 1...
# 1  MULTIPOLYGON (((1138209.365 1673609.179, 11381...
# 2  POLYGON ((1107777.593 1780522.269, 1107845.409...
# 3  MULTIPOLYGON (((897904.035 1961082.190, 897886...
# 4  POLYGON ((932712.687 1696168.692, 932781.680 1...

# %%
sig_area = gpd.GeoDataFrame.from_file('./SIG_202005/SIG.shp', encoding='cp949')
sig_area.head()
# Out:
#   SIG_CD    SIG_ENG_NM SIG_KOR_NM  \
# 0  11110     Jongno-gu        종로구
# 1  11140       Jung-gu         중구
# 2  11170    Yongsan-gu        용산구
# 3  11200  Seongdong-gu        성동구
# 4  11215   Gwangjin-gu        광진구
#
#                                             geometry
# 0  POLYGON ((956615.453 1953567.199, 956621.579 1...
# 1  POLYGON ((957890.386 1952616.746, 957909.908 1...
# 2  POLYGON ((953115.761 1950834.084, 953114.206 1...
# 3  POLYGON ((959681.109 1952649.605, 959842.412 1...
# 4  POLYGON ((964825.058 1952633.250, 964875.565 1...

# %%
adCode_excel = pd.read_excel('./adCode_20201001.xlsx', sheet_name='법정동코드 연계 자료분석용', dtype='str')
adCode_excel.head()
# Out:
#   행정구역분류와 행정기관 및 법정동코드 연계표(2020.10.1.기준) Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0                                     시도        시군구      행정구역명  행정동(행정기관명)
# 1                                  서울특별시      서울특별시      서울특별시       서울특별시
# 2                                  서울특별시        종로구        종로구         종로구
# 3                                  서울특별시        종로구      청운효자동       청운효자동
# 4                                  서울특별시        종로구      청운효자동       청운효자동
#
#   Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9  \
# 0        법정동     행정구역코드      행정기관코드   행정기관 생성일       법정동코드   법정동 관할지역
# 1      서울특별시         11  1100000000   19880423  1100000000        NaN
# 2        종로구      11010  1111000000   19880423  1111000000        NaN
# 3        청운동    1101072  1111051500   20081101  1111010100        NaN
# 4        신교동    1101072  1111051500   20081101  1111010200        NaN
#
#           Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0            행정동 영문명칭          비고    연계표 정비결과
# 1               Seoul         NaN         NaN
# 2           Jongno-gu         NaN         NaN
# 3  Cheongunhyoja-dong         NaN         NaN
# 4  Cheongunhyoja-dong         NaN         NaN

# %%
columnName = {
    '행정구역분류와 행정기관 및 법정동코드 연계표(2020.10.1.기준)': '시도',
    'Unnamed: 1': '시군구',
    'Unnamed: 2':  '행정구역명',
    'Unnamed: 3': '행정동(행정기관명)',
    'Unnamed: 4': '법정동',
    'Unnamed: 5': '행정구역코드',
    'Unnamed: 6': '행정기관코드',
    'Unnamed: 7': '행정기관 생성일',
    'Unnamed: 8': '법정동코드',
    'Unnamed: 9': '법정동 관할지역',
    'Unnamed: 10': '행정동 영문명칭',
    'Unnamed: 11': '비고',
    'Unnamed: 12': '연계표 정비결과'
}
adCode_excel_rename = adCode_excel.rename(columnName, axis='columns')
adCode_excel_rename.head()
# Out:
#       시도    시군구  행정구역명  행정동(행정기관명)    법정동   행정구역코드      행정기관코드  행정기관 생성일  \
# 0     시도    시군구  행정구역명  행정동(행정기관명)    법정동   행정구역코드      행정기관코드  행정기관 생성일
# 1  서울특별시  서울특별시  서울특별시       서울특별시  서울특별시       11  1100000000  19880423
# 2  서울특별시    종로구    종로구         종로구    종로구    11010  1111000000  19880423
# 3  서울특별시    종로구  청운효자동       청운효자동    청운동  1101072  1111051500  20081101
# 4  서울특별시    종로구  청운효자동       청운효자동    신교동  1101072  1111051500  20081101
#
#         법정동코드  법정동 관할지역            행정동 영문명칭   비고  연계표 정비결과
# 0       법정동코드  법정동 관할지역            행정동 영문명칭   비고  연계표 정비결과
# 1  1100000000       NaN               Seoul  NaN       NaN
# 2  1111000000       NaN           Jongno-gu  NaN       NaN
# 3  1111010100       NaN  Cheongunhyoja-dong  NaN       NaN
# 4  1111010200       NaN  Cheongunhyoja-dong  NaN       NaN

# %%
adCode_EMD = adCode_excel_rename[adCode_excel_rename['행정구역코드'].str.len()>6].copy()
adCode_EMD.head()
# Out:
#       시도  시군구  행정구역명 행정동(행정기관명)  법정동   행정구역코드      행정기관코드  행정기관 생성일  \
# 3  서울특별시  종로구  청운효자동      청운효자동  청운동  1101072  1111051500  20081101
# 4  서울특별시  종로구  청운효자동      청운효자동  신교동  1101072  1111051500  20081101
# 5  서울특별시  종로구  청운효자동      청운효자동  궁정동  1101072  1111051500  20081101
# 6  서울특별시  종로구  청운효자동      청운효자동  효자동  1101072  1111051500  20081101
# 7  서울특별시  종로구  청운효자동      청운효자동  창성동  1101072  1111051500  20081101
#
#         법정동코드 법정동 관할지역            행정동 영문명칭   비고 연계표 정비결과
# 3  1111010100      NaN  Cheongunhyoja-dong  NaN      NaN
# 4  1111010200      NaN  Cheongunhyoja-dong  NaN      NaN
# 5  1111010300      NaN  Cheongunhyoja-dong  NaN      NaN
# 6  1111010400      NaN  Cheongunhyoja-dong  NaN      NaN
# 7  1111010500      NaN  Cheongunhyoja-dong  NaN      NaN

# %%
adCode_EMD.loc[:,'EMD_CD'] = adCode_EMD['법정동코드'].str.slice_replace(start=8, stop=10, repl='')
#gyeonggi_dentist['geometry'] = gyeonggi_dentist.apply(lambda row : Point([row['경도'], row['위도']]), axis=1)
adCode_EMD.head()
# Out:
#       시도  시군구  행정구역명 행정동(행정기관명)  법정동   행정구역코드      행정기관코드  행정기관 생성일  \
# 3  서울특별시  종로구  청운효자동      청운효자동  청운동  1101072  1111051500  20081101
# 4  서울특별시  종로구  청운효자동      청운효자동  신교동  1101072  1111051500  20081101
# 5  서울특별시  종로구  청운효자동      청운효자동  궁정동  1101072  1111051500  20081101
# 6  서울특별시  종로구  청운효자동      청운효자동  효자동  1101072  1111051500  20081101
# 7  서울특별시  종로구  청운효자동      청운효자동  창성동  1101072  1111051500  20081101
#
#         법정동코드 법정동 관할지역            행정동 영문명칭   비고 연계표 정비결과    EMD_CD
# 3  1111010100      NaN  Cheongunhyoja-dong  NaN      NaN  11110101
# 4  1111010200      NaN  Cheongunhyoja-dong  NaN      NaN  11110102
# 5  1111010300      NaN  Cheongunhyoja-dong  NaN      NaN  11110103
# 6  1111010400      NaN  Cheongunhyoja-dong  NaN      NaN  11110104
# 7  1111010500      NaN  Cheongunhyoja-dong  NaN      NaN  11110105

# %%
adCode_EMD.drop(['행정기관코드','행정동(행정기관명)','행정기관 생성일','법정동코드','법정동 관할지역','행정동 영문명칭','비고','연계표 정비결과'], axis='columns', inplace=True)
adCode_EMD.head()
# Out:
#       시도  시군구  행정구역명  법정동   행정구역코드    EMD_CD
# 3  서울특별시  종로구  청운효자동  청운동  1101072  11110101
# 4  서울특별시  종로구  청운효자동  신교동  1101072  11110102
# 5  서울특별시  종로구  청운효자동  궁정동  1101072  11110103
# 6  서울특별시  종로구  청운효자동  효자동  1101072  11110104
# 7  서울특별시  종로구  청운효자동  창성동  1101072  11110105

# %%
"""
for ad_index, ad_item in adCode_EMD.iterrows():
    for emd_index, emd_item in emd_area.iterrows():
        if(ad_item['EMD_CD'] == emd_item['EMD_CD']):
            if(ad_item['법정동'] != emd_item['EMD_KOR_NM']):
                print(f"{ad_item['EMD_CD']} 코드는 ad는 {ad_item['법정동']}, EMD는 {emd_item['EMD_KOR_NM']}로 다릅니다.")
"""
# Out:
# '\nfor ad_index, ad_item in adCode_EMD.iterrows():\n    for emd_index, emd_item in emd_area.iterrows():\n        if(ad_item[\'EMD_CD\'] == emd_item[\'EMD_CD\']):\n            if(ad_item[\'법정동\'] != emd_item[\'EMD_KOR_NM\']):\n                print(f"{ad_item[\'EMD_CD\']} 코드는 ad는 {ad_item[\'법정동\']}, EMD는 {emd_item[\'EMD_KOR_NM\']}로 다릅니다.")\n'

# %%
ad_area = pd.merge(adCode_EMD, emd_area, on='EMD_CD', how= 'inner')
ad_area.head()
# Out:
#       시도  시군구  행정구역명  법정동   행정구역코드    EMD_CD       EMD_ENG_NM EMD_KOR_NM  \
# 0  서울특별시  종로구  청운효자동  청운동  1101072  11110101    Cheongun-dong        청운동
# 1  서울특별시  종로구  청운효자동  신교동  1101072  11110102      Singyo-dong        신교동
# 2  서울특별시  종로구  청운효자동  궁정동  1101072  11110103   Gungjeong-dong        궁정동
# 3  서울특별시  종로구  청운효자동  효자동  1101072  11110104       Hyoja-dong        효자동
# 4  서울특별시  종로구  청운효자동  창성동  1101072  11110105  Changseong-dong        창성동
#
#                                             geometry
# 0  POLYGON ((953700.022 1954605.065, 953693.871 1...
# 1  POLYGON ((953233.465 1953996.984, 953235.183 1...
# 2  POLYGON ((953560.228 1954257.466, 953561.190 1...
# 3  POLYGON ((953519.843 1953890.785, 953518.489 1...
# 4  POLYGON ((953516.123 1953734.362, 953516.526 1...

# %%
ad_area.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21327 entries, 0 to 21326
# Data columns (total 9 columns):
# 시도            21327 non-null object
# 시군구           21327 non-null object
# 행정구역명         21327 non-null object
# 법정동           21327 non-null object
# 행정구역코드        21327 non-null object
# EMD_CD        21327 non-null object
# EMD_ENG_NM    21327 non-null object
# EMD_KOR_NM    21327 non-null object
# geometry      21327 non-null geometry
# dtypes: geometry(1), object(8)
# memory usage: 1.6+ MB

# %%
ad_area_gdf = gpd.GeoDataFrame(ad_area, geometry=ad_area['geometry'],crs = {'init': 'epsg:4326'})
ad_area_gdf.drop(['EMD_ENG_NM','EMD_CD'], axis='columns', inplace=True)
ad_area_gdf.head()
# Out:
#       시도  시군구  행정구역명  법정동   행정구역코드 EMD_KOR_NM  \
# 0  서울특별시  종로구  청운효자동  청운동  1101072        청운동
# 1  서울특별시  종로구  청운효자동  신교동  1101072        신교동
# 2  서울특별시  종로구  청운효자동  궁정동  1101072        궁정동
# 3  서울특별시  종로구  청운효자동  효자동  1101072        효자동
# 4  서울특별시  종로구  청운효자동  창성동  1101072        창성동
#
#                                             geometry
# 0  POLYGON ((953700.022 1954605.065, 953693.871 1...
# 1  POLYGON ((953233.465 1953996.984, 953235.183 1...
# 2  POLYGON ((953560.228 1954257.466, 953561.190 1...
# 3  POLYGON ((953519.843 1953890.785, 953518.489 1...
# 4  POLYGON ((953516.123 1953734.362, 953516.526 1...

# %%
ad_area_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 21327 entries, 0 to 21326
# Data columns (total 7 columns):
# 시도            21327 non-null object
# 시군구           21327 non-null object
# 행정구역명         21327 non-null object
# 법정동           21327 non-null object
# 행정구역코드        21327 non-null object
# EMD_KOR_NM    21327 non-null object
# geometry      21327 non-null geometry
# dtypes: geometry(1), object(6)
# memory usage: 1.3+ MB

# %%
#ad_area_gdf.plot(column='행정구역명',figsize=(25,25),cmap='twilight_shifted')

# %%
"""
seoul_ad_area = ad_area_gdf[ad_area_gdf['시도']=='서울특별시']
seoul_ad_area.plot(column='행정동(행정기관명)',figsize=(25,25),cmap='twilight_shifted')
"""
# Out:
# "\nseoul_ad_area = ad_area_gdf[ad_area_gdf['시도']=='서울특별시']\nseoul_ad_area.plot(column='행정동(행정기관명)',figsize=(25,25),cmap='twilight_shifted')\n"

# %%
"""
gyeonggi_ad_area = ad_area_gdf[ad_area_gdf['시도']=='경기도']
gyeonggi_ad_area.plot(column='행정동(행정기관명)',figsize=(25,25),cmap='twilight_shifted')
"""
# Out:
# "\ngyeonggi_ad_area = ad_area_gdf[ad_area_gdf['시도']=='경기도']\ngyeonggi_ad_area.plot(column='행정동(행정기관명)',figsize=(25,25),cmap='twilight_shifted')\n"

# %%
"""
gwanggyo_ad_area = ad_area_gdf[ad_area_gdf['행정구역명'].str.contains('광교')]
gwanggyo_ad_area.head(10)
gwanggyo_ad_area.plot(column='행정동(행정기관명)',figsize=(25,25),cmap='cividis')
"""
# Out:
# "\ngwanggyo_ad_area = ad_area_gdf[ad_area_gdf['행정구역명'].str.contains('광교')]\ngwanggyo_ad_area.head(10)\ngwanggyo_ad_area.plot(column='행정동(행정기관명)',figsize=(25,25),cmap='cividis')\n"

# %%
"""
dongtan_ad_area = ad_area_gdf[ad_area_gdf['행정구역명'].str.contains('동탄')]
dongtan_ad_area.head(10)
plt.rc('font', family='NanumGothic')
dongtan_ad_area.plot(column='행정동(행정기관명)',figsize=(25,25),cmap='twilight_shifted',categorical=True,legend=True)
"""
# Out:
# "\ndongtan_ad_area = ad_area_gdf[ad_area_gdf['행정구역명'].str.contains('동탄')]\ndongtan_ad_area.head(10)\nplt.rc('font', family='NanumGothic')\ndongtan_ad_area.plot(column='행정동(행정기관명)',figsize=(25,25),cmap='twilight_shifted',categorical=True,legend=True)\n"

# %%
#ad_area_gdf.to_file("destrict.geojson", driver='GeoJSON')

# %%
import sqlalchemy as sal
from geoalchemy2 import Geometry
from geoalchemy2 import Geometry, WKTElement
columnName = {
    "시도":"sido",
    "시군구": "sigungu",
    "행정구역명": "adCity",
    "법정동": "legalCity",
    "행정구역코드": "emdCode",
    "EMD_KOR_NM":"emdName"
}
ad_area_gdf = ad_area_gdf.rename(columnName, axis='columns')
ad_area_gdf.head()
#ad_area_gdf['geometry'] = ad_area_gdf['geometry'].apply(lambda x: WKTElement(x.wkt, srid=4326))
#ad_area_gdf.drop('geometry', 1, inplace=True)
# Out:
#     sido sigungu adCity legalCity  emdCode emdName  \
# 0  서울특별시     종로구  청운효자동       청운동  1101072     청운동
# 1  서울특별시     종로구  청운효자동       신교동  1101072     신교동
# 2  서울특별시     종로구  청운효자동       궁정동  1101072     궁정동
# 3  서울특별시     종로구  청운효자동       효자동  1101072     효자동
# 4  서울특별시     종로구  청운효자동       창성동  1101072     창성동
#
#                                             geometry
# 0  POLYGON ((953700.022 1954605.065, 953693.871 1...
# 1  POLYGON ((953233.465 1953996.984, 953235.183 1...
# 2  POLYGON ((953560.228 1954257.466, 953561.190 1...
# 3  POLYGON ((953519.843 1953890.785, 953518.489 1...
# 4  POLYGON ((953516.123 1953734.362, 953516.526 1...

# %%
#engine = sal.create_engine('mysql+mysqldb://admin:jeewon0109!@database-1.c2g4zseshvri.ap-northeast-2.rds.amazonaws.com:3306/chikachika_db_dev?charset=utf8',echo=False)
#ad_area_gdf.to_sql('cities', con=engine,if_exists='append', index=False, dtype={'geometry': Geometry('polygon', srid=4326)})
#ad_area_gdf.to_sql('cities', con=engine,if_exists='append', index=False)
import pymysql
conn = pymysql.connect(host='database-1.c2g4zseshvri.ap-northeast-2.rds.amazonaws.com', user='admin', password='jeewon0109!',
                       db='chikachika_db_dev', charset='utf8')
 
curs = conn.cursor()
for ad_index, ad_item in ad_area_gdf.iterrows():
    print(ad_index)
    if ad_item['geometry'].geom_type == 'MultiPolygon':
        sql = """insert into cities (sido, sigungu, adCity, legalCity, emdCode, emdName, geometry) values (%s, %s, %s, %s, %s, %s, GeomFromText(%s))"""
    elif ad_item['geometry'].geom_type == 'Polygon':
        sql = """insert into cities (sido, sigungu, adCity, legalCity, emdCode, emdName, geometry) values (%s, %s, %s, %s, %s, %s, ST_PolyFromText(%s))"""
    curs.execute(sql, (ad_item['sido'], ad_item['sigungu'], ad_item['adCity'],ad_item['legalCity'],ad_item['emdCode'],ad_item['emdName'],str(ad_item['geometry'])))
    conn.commit() 
conn.close()
# Out:
# MULTIPOLYGON (((956124.0925625653 1951881.39190327, 956121.6629452362 1951873.944555367, 956118.4511697056 1951863.774366793, 956118.0578630975 1951862.74683456, 956117.2682826025 1951861.074643954, 956115.8620205816 1951858.100208197, 956115.2371407552 1951856.760020605, 956113.887264694 1951853.862257222, 956111.6496080321 1951850.001561441, 956110.7166575727 1951848.438091277, 956110.0893063715 1951847.385810097, 956108.5758135199 1951844.925752669, 956106.8930511841 1951842.591546775, 956105.6336077873 1951840.72392175, 956105.3830446436 1951840.600297103, 956102.4230957171 1951839.272495285, 956101.7975706622 1951839.12986731, 956100.3393226201 1951838.039009326, 956098.5518850491 1951836.70098968, 956094.6708919326 1951832.285219367, 956093.1251711524 1951832.418371949, 956080.3970051014 1951840.732829401, 956078.1665217539 1951842.182127811, 956080.7467239532 1951845.604168666, 956081.4494828611 1951846.550089164, 956082.2720533004 1951847.65731414, 956082.5242760225 1951848.093814046, 956082.8239731241 1951848.623027688, 956082.7803056927 1951849.248027805, 956082.7379638017 1951850.122928289, 956082.5691075897 1951850.703609109, 956082.4012297686 1951851.280286222, 956082.2190262857 1951851.606132296, 956081.8595855153 1951852.251800323, 956079.187476417 1951854.683078259, 956077.195823333 1951856.493975427, 956077.1827673917 1951856.670979117, 956077.6399477711 1951857.679179628, 956078.0302873994 1951858.71272542, 956078.4987044997 1951859.954779654, 956079.0887981378 1951860.013626671, 956079.5770775082 1951861.042654443, 956079.7681548772 1951861.447490533, 956080.0208495015 1951861.972954967, 956081.1741730663 1951864.375944734, 956082.7464890305 1951866.429840577, 956082.6548491203 1951866.491304064, 956082.0930674749 1951866.870144639, 956083.5043250766 1951869.655624003, 956084.3973523732 1951871.419231875, 956084.6084270802 1951871.824961514, 956085.0285666806 1951872.634432198, 956084.8760384229 1951872.901142723, 956084.5798881882 1951873.417522829, 956085.2763944448 1951875.069214954, 956085.1223785065 1951875.620827803, 956084.9546544637 1951876.226493359, 956082.8741968077 1951876.937269428, 956080.2149988796 1951877.845043451, 956079.9434948829 1951877.165735835, 956075.8129387394 1951878.657101027, 956072.8675444403 1951879.696344978, 956073.0108312619 1951880.891141943, 956073.292269049 1951883.25477275, 956073.9441951227 1951886.490114639, 956074.5119428617 1951889.309057494, 956074.9558895787 1951890.649205215, 956075.2758170572 1951891.60015523, 956076.8952980231 1951896.3268104, 956077.3810848572 1951897.639746183, 956077.6822825067 1951898.451847025, 956078.6681503112 1951900.945691657, 956081.4741499791 1951906.229844205, 956085.3390727559 1951907.238961875, 956091.2100262692 1951904.247917232, 956100.4529947723 1951899.610589816, 956109.3751996803 1951895.183886498, 956116.7097557917 1951891.466344964, 956125.2368129818 1951887.172689257, 956126.075303932 1951886.758393534, 956124.942455449 1951883.692540916, 956124.0925625653 1951881.39190327)), ((955983.8621421074 1951927.493924805, 955985.166403742 1951906.338840706, 956012.7576981635 1951907.754908665, 956014.4205552476 1951907.844052033, 956034.0388943349 1951908.900559964, 956034.508866145 1951908.928055968, 956053.8168006201 1951910.075177377, 956055.3357391134 1951884.162718456, 956056.549127838 1951859.821298841, 956057.7133841091 1951840.728195392, 956062.5734116629 1951767.573512653, 956066.4997842915 1951706.856176308, 956068.5772361821 1951674.48214878, 956053.0810389547 1951647.543353427, 956031.6016254383 1951641.065723327, 956001.0865195385 1951633.261527714, 956000.6282160212 1951649.945778662, 955998.3076545531 1951683.601623613, 955997.2740635349 1951700.756752713, 955994.8940126857 1951740.723575653, 955994.0871266592 1951753.504122517, 955993.0553734163 1951753.47860658, 955989.7432029472 1951753.215278922, 955985.4151031758 1951752.894363241, 955975.5868773521 1951752.165782921, 955966.1484960739 1951751.435134788, 955961. ...
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-58-309866103039> in <module>
#      13     elif ad_item['geometry'].geom_type == 'Polygon':
#      14         sql = """insert into cities (sido, sigungu, adCity, legalCity, emdCode, emdName, geometry) values (%s, %s, %s, %s, %s, %s, ST_PolyFromText(%s))"""
# ---> 15     curs.execute(sql, (ad_item['sido'], ad_item['sigungu'], ad_item['adCity'],ad_item['legalCity'],ad_item['emdCode'],ad_item['emdName'],str(ad_item['geometry'])))
#      16     conn.commit()
#      17 conn.close()
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     503                 sql = sql.encode(self.encoding, 'surrogateescape')
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#     507
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     722         else:
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#     726         if result.server_status is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1067     def read(self):
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#    1071             if first_packet.is_ok_packet():
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     674             if self._result is not None and self._result.unbuffered_active is True:
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#     678
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in raise_for_error(self)
#     221         errno = self.read_uint16()
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#     225     def dump(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     105     if errorclass is None:
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (1416, 'Cannot get geometry object from data you send to the GEOMETRY field')

# %%
ad_area_gdf.iloc[161]['geometry']
ad_area_gdf.iloc[161]['geometry']
