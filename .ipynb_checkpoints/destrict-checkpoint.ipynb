# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon, LineString
import matplotlib
import pandas as pd
print (plt.rcParams['font.size'] ) 
print (plt.rcParams['font.family'] )
# Out:
# 10.0
# ['sans-serif']

# %%
emd_area = gpd.GeoDataFrame.from_file('./EMD_202005/EMD.shp', encoding='cp949')
emd_area.head()
# Out:
#      EMD_CD       EMD_ENG_NM EMD_KOR_NM  \
# 0  11110101    Cheongun-dong        청운동
# 1  11110102      Singyo-dong        신교동
# 2  11110103   Gungjeong-dong        궁정동
# 3  11110104       Hyoja-dong        효자동
# 4  11110105  Changseong-dong        창성동
#
#                                             geometry
# 0  POLYGON ((953700.022 1954605.065, 953693.871 1...
# 1  POLYGON ((953233.465 1953996.984, 953235.183 1...
# 2  POLYGON ((953560.228 1954257.466, 953561.190 1...
# 3  POLYGON ((953519.843 1953890.785, 953518.489 1...
# 4  POLYGON ((953516.123 1953734.362, 953516.526 1...

# %%
ctprvn_area = gpd.GeoDataFrame.from_file('./CTPRVN_202005/CTPRVN.shp', encoding='cp949')
ctprvn_area.head()
# Out:
#   CTPRVN_CD CTP_ENG_NM CTP_KOR_NM  \
# 0        11      Seoul      서울특별시
# 1        26      Busan      부산광역시
# 2        27      Daegu      대구광역시
# 3        28    Incheon      인천광역시
# 4        29    Gwangju      광주광역시
#
#                                             geometry
# 0  POLYGON ((966987.226 1941110.946, 966987.119 1...
# 1  MULTIPOLYGON (((1138209.365 1673609.179, 11381...
# 2  POLYGON ((1107777.593 1780522.269, 1107845.409...
# 3  MULTIPOLYGON (((897904.035 1961082.190, 897886...
# 4  POLYGON ((932712.687 1696168.692, 932781.680 1...

# %%
sig_area = gpd.GeoDataFrame.from_file('./SIG_202005/SIG.shp', encoding='cp949')
sig_area.head()
# Out:
#   SIG_CD    SIG_ENG_NM SIG_KOR_NM  \
# 0  11110     Jongno-gu        종로구
# 1  11140       Jung-gu         중구
# 2  11170    Yongsan-gu        용산구
# 3  11200  Seongdong-gu        성동구
# 4  11215   Gwangjin-gu        광진구
#
#                                             geometry
# 0  POLYGON ((956615.453 1953567.199, 956621.579 1...
# 1  POLYGON ((957890.386 1952616.746, 957909.908 1...
# 2  POLYGON ((953115.761 1950834.084, 953114.206 1...
# 3  POLYGON ((959681.109 1952649.605, 959842.412 1...
# 4  POLYGON ((964825.058 1952633.250, 964875.565 1...

# %%
adCode_excel = pd.read_excel('./adCode_20201001.xlsx', sheet_name='법정동코드 연계 자료분석용', dtype='str')
adCode_excel.head()
# Out:
#   행정구역분류와 행정기관 및 법정동코드 연계표(2020.10.1.기준) Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0                                     시도        시군구      행정구역명  행정동(행정기관명)
# 1                                  서울특별시      서울특별시      서울특별시       서울특별시
# 2                                  서울특별시        종로구        종로구         종로구
# 3                                  서울특별시        종로구      청운효자동       청운효자동
# 4                                  서울특별시        종로구      청운효자동       청운효자동
#
#   Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9  \
# 0        법정동     행정구역코드      행정기관코드   행정기관 생성일       법정동코드   법정동 관할지역
# 1      서울특별시         11  1100000000   19880423  1100000000        NaN
# 2        종로구      11010  1111000000   19880423  1111000000        NaN
# 3        청운동    1101072  1111051500   20081101  1111010100        NaN
# 4        신교동    1101072  1111051500   20081101  1111010200        NaN
#
#           Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0            행정동 영문명칭          비고    연계표 정비결과
# 1               Seoul         NaN         NaN
# 2           Jongno-gu         NaN         NaN
# 3  Cheongunhyoja-dong         NaN         NaN
# 4  Cheongunhyoja-dong         NaN         NaN

# %%
columnName = {
    '행정구역분류와 행정기관 및 법정동코드 연계표(2020.10.1.기준)': '시도',
    'Unnamed: 1': '시군구',
    'Unnamed: 2':  '행정구역명',
    'Unnamed: 3': '행정동(행정기관명)',
    'Unnamed: 4': '법정동',
    'Unnamed: 5': '행정구역코드',
    'Unnamed: 6': '행정기관코드',
    'Unnamed: 7': '행정기관 생성일',
    'Unnamed: 8': '법정동코드',
    'Unnamed: 9': '법정동 관할지역',
    'Unnamed: 10': '행정동 영문명칭',
    'Unnamed: 11': '비고',
    'Unnamed: 12': '연계표 정비결과'
}
adCode_excel_rename = adCode_excel.rename(columnName, axis='columns')
adCode_excel_rename.head()
# Out:
#       시도    시군구  행정구역명  행정동(행정기관명)    법정동   행정구역코드      행정기관코드  행정기관 생성일  \
# 0     시도    시군구  행정구역명  행정동(행정기관명)    법정동   행정구역코드      행정기관코드  행정기관 생성일
# 1  서울특별시  서울특별시  서울특별시       서울특별시  서울특별시       11  1100000000  19880423
# 2  서울특별시    종로구    종로구         종로구    종로구    11010  1111000000  19880423
# 3  서울특별시    종로구  청운효자동       청운효자동    청운동  1101072  1111051500  20081101
# 4  서울특별시    종로구  청운효자동       청운효자동    신교동  1101072  1111051500  20081101
#
#         법정동코드  법정동 관할지역            행정동 영문명칭   비고  연계표 정비결과
# 0       법정동코드  법정동 관할지역            행정동 영문명칭   비고  연계표 정비결과
# 1  1100000000       NaN               Seoul  NaN       NaN
# 2  1111000000       NaN           Jongno-gu  NaN       NaN
# 3  1111010100       NaN  Cheongunhyoja-dong  NaN       NaN
# 4  1111010200       NaN  Cheongunhyoja-dong  NaN       NaN

# %%
adCode_EMD = adCode_excel_rename[adCode_excel_rename['행정구역코드'].str.len()>6].copy()
adCode_EMD.head()
# Out:
#       시도  시군구  행정구역명 행정동(행정기관명)  법정동   행정구역코드      행정기관코드  행정기관 생성일  \
# 3  서울특별시  종로구  청운효자동      청운효자동  청운동  1101072  1111051500  20081101
# 4  서울특별시  종로구  청운효자동      청운효자동  신교동  1101072  1111051500  20081101
# 5  서울특별시  종로구  청운효자동      청운효자동  궁정동  1101072  1111051500  20081101
# 6  서울특별시  종로구  청운효자동      청운효자동  효자동  1101072  1111051500  20081101
# 7  서울특별시  종로구  청운효자동      청운효자동  창성동  1101072  1111051500  20081101
#
#         법정동코드 법정동 관할지역            행정동 영문명칭   비고 연계표 정비결과
# 3  1111010100      NaN  Cheongunhyoja-dong  NaN      NaN
# 4  1111010200      NaN  Cheongunhyoja-dong  NaN      NaN
# 5  1111010300      NaN  Cheongunhyoja-dong  NaN      NaN
# 6  1111010400      NaN  Cheongunhyoja-dong  NaN      NaN
# 7  1111010500      NaN  Cheongunhyoja-dong  NaN      NaN

# %%
adCode_EMD.loc[:,'EMD_CD'] = adCode_EMD['법정동코드'].str.slice_replace(start=8, stop=10, repl='')
#gyeonggi_dentist['geometry'] = gyeonggi_dentist.apply(lambda row : Point([row['경도'], row['위도']]), axis=1)
adCode_EMD.head()
# Out:
#       시도  시군구  행정구역명 행정동(행정기관명)  법정동   행정구역코드      행정기관코드  행정기관 생성일  \
# 3  서울특별시  종로구  청운효자동      청운효자동  청운동  1101072  1111051500  20081101
# 4  서울특별시  종로구  청운효자동      청운효자동  신교동  1101072  1111051500  20081101
# 5  서울특별시  종로구  청운효자동      청운효자동  궁정동  1101072  1111051500  20081101
# 6  서울특별시  종로구  청운효자동      청운효자동  효자동  1101072  1111051500  20081101
# 7  서울특별시  종로구  청운효자동      청운효자동  창성동  1101072  1111051500  20081101
#
#         법정동코드 법정동 관할지역            행정동 영문명칭   비고 연계표 정비결과    EMD_CD
# 3  1111010100      NaN  Cheongunhyoja-dong  NaN      NaN  11110101
# 4  1111010200      NaN  Cheongunhyoja-dong  NaN      NaN  11110102
# 5  1111010300      NaN  Cheongunhyoja-dong  NaN      NaN  11110103
# 6  1111010400      NaN  Cheongunhyoja-dong  NaN      NaN  11110104
# 7  1111010500      NaN  Cheongunhyoja-dong  NaN      NaN  11110105

# %%
adCode_EMD.drop(['행정기관코드','행정기관 생성일','법정동코드','법정동 관할지역','행정동 영문명칭','비고','연계표 정비결과'], axis='columns', inplace=True)
adCode_EMD.head()
# Out:
#       시도  시군구  행정구역명 행정동(행정기관명)  법정동   행정구역코드    EMD_CD
# 3  서울특별시  종로구  청운효자동      청운효자동  청운동  1101072  11110101
# 4  서울특별시  종로구  청운효자동      청운효자동  신교동  1101072  11110102
# 5  서울특별시  종로구  청운효자동      청운효자동  궁정동  1101072  11110103
# 6  서울특별시  종로구  청운효자동      청운효자동  효자동  1101072  11110104
# 7  서울특별시  종로구  청운효자동      청운효자동  창성동  1101072  11110105

# %%
for ad_index, ad_item in adCode_EMD.iterrows():
    for emd_index, emd_item in emd_area.iterrows():
        if(ad_item['EMD_CD'] == emd_item['EMD_CD']):
            if(ad_item['법정동'] != emd_item['EMD_KOR_NM']):
                print(f"{ad_item['EMD_CD']} 코드는 ad는 {ad_item['법정동']}, EMD는 {emd_item['EMD_KOR_NM']}로 다릅니다.")
# Out:
# 26710250 코드는 ad는 동부리, EMD는 기장읍로 다릅니다.
# 26710250 코드는 ad는 교리, EMD는 기장읍로 다릅니다.
# 26710250 코드는 ad는 신천리, EMD는 기장읍로 다릅니다.
# 26710250 코드는 ad는 죽성리, EMD는 기장읍로 다릅니다.
# 26710250 코드는 ad는 서부리, EMD는 기장읍로 다릅니다.
# 26710250 코드는 ad는 대라리, EMD는 기장읍로 다릅니다.
# 26710250 코드는 ad는 청강리, EMD는 기장읍로 다릅니다.
# 26710250 코드는 ad는 대변리, EMD는 기장읍로 다릅니다.
# 26710250 코드는 ad는 연화리, EMD는 기장읍로 다릅니다.
# 26710250 코드는 ad는 만화리, EMD는 기장읍로 다릅니다.
# 26710250 코드는 ad는 석산리, EMD는 기장읍로 다릅니다.
# 26710250 코드는 ad는 당사리, EMD는 기장읍로 다릅니다.
# 26710250 코드는 ad는 시랑리, EMD는 기장읍로 다릅니다.
# 26710250 코드는 ad는 내리, EMD는 기장읍로 다릅니다.
# 26710253 코드는 ad는 좌천리, EMD는 장안읍로 다릅니다.
# 26710253 코드는 ad는 효암리, EMD는 장안읍로 다릅니다.
# 26710253 코드는 ad는 고리, EMD는 장안읍로 다릅니다.
# 26710253 코드는 ad는 좌동리, EMD는 장안읍로 다릅니다.
# 26710253 코드는 ad는 장안리, EMD는 장안읍로 다릅니다.
# 26710253 코드는 ad는 덕선리, EMD는 장안읍로 다릅니다.
# 26710253 코드는 ad는 용소리, EMD는 장안읍로 다릅니다.
# 26710253 코드는 ad는 기룡리, EMD는 장안읍로 다릅니다.
# 26710253 코드는 ad는 명례리, EMD는 장안읍로 다릅니다.
# 26710253 코드는 ad는 월내리, EMD는 장안읍로 다릅니다.
# 26710253 코드는 ad는 반룡리, EMD는 장안읍로 다릅니다.
# 26710253 코드는 ad는 임랑리, EMD는 장안읍로 다릅니다.
# 26710253 코드는 ad는 오리, EMD는 장안읍로 다릅니다.
# 26710253 코드는 ad는 길천리, EMD는 장안읍로 다릅니다.
# 26710310 코드는 ad는 삼성리, EMD는 일광면로 다릅니다.
# 26710310 코드는 ad는 이천리, EMD는 일광면로 다릅니다.
# 26710310 코드는 ad는 학리, EMD는 일광면로 다릅니다.
# 26710310 코드는 ad는 동백리, EMD는 일광면로 다릅니다.
# 26710310 코드는 ad는 문중리, EMD는 일광면로 다릅니다.
# 26710310 코드는 ad는 신평리, EMD는 일광면로 다릅니다.
# 26710310 코드는 ad는 칠암리, EMD는 일광면로 다릅니다.
# 26710310 코드는 ad는 문동리, EMD는 일광면로 다릅니다.
# 26710310 코드는 ad는 청광리, EMD는 일광면로 다릅니다.
# 26710310 코드는 ad는 원리, EMD는 일광면로 다릅니다.
# 26710310 코드는 ad는 화전리, EMD는 일광면로 다릅니다.
# 26710310 코드는 ad는 횡계리, EMD는 일광면로 다릅니다.
# 26710310 코드는 ad는 용천리, EMD는 일광면로 다릅니다.
# 26710256 코드는 ad는 방곡리, EMD는 정관읍로 다릅니다.
# 26710256 코드는 ad는 매학리, EMD는 정관읍로 다릅니다.
# 26710256 코드는 ad는 임곡리, EMD는 정관읍로 다릅니다.
# 26710256 코드는 ad는 월평리, EMD는 정관읍로 다릅니다.
# 26710256 코드는 ad는 달산리, EMD는 정관읍로 다릅니다.
# 26710256 코드는 ad는 병산리, EMD는 정관읍로 다릅니다.
# 26710256 코드는 ad는 모전리, EMD는 정관읍로 다릅니다.
# 26710256 코드는 ad는 용수리, EMD는 정관읍로 다릅니다.
# 26710256 코드는 ad는 두명리, EMD는 정관읍로 다릅니다.
# 26710256 코드는 ad는 예림리, EMD는 정관읍로 다릅니다.
# 26710330 코드는 ad는 와여리, EMD는 철마면로 다릅니다.
# 26710330 코드는 ad는 장전리, EMD는 철마면로 다릅니다.
# 26710330 코드는 ad는 백길리, EMD는 철마면로 다릅니다.
# 26710330 코드는 ad는 송정리, EMD는 철마면로 다릅니다.
# 26710330 코드는 ad는 웅천리, EMD는 철마면로 다릅니다.
# 26710330 코드는 ad는 연구리, EMD는 철마면로 다릅니다.
# 26710330 코드는 ad는 구칠리, EMD는 철마면로 다릅니다.
# 26710330 코드는 ad는 이곡리, EMD는 철마면로 다릅니다.
# 26710330 코드는 ad는 고촌리, EMD는 철마면로 다릅니다.
# 26710330 코드는 ad는 안평리, EMD는 철마면로 다릅니다.
# 26710330 코드는 ad는 임기리, EMD는 철마면로 다릅니다.
# 27710250 코드는 ad는 천내리, EMD는 화원읍로 다릅니다.
# 27710250 코드는 ad는 구라리, EMD는 화원읍로 다릅니다.
# 27710250 코드는 ad는 성산리, EMD는 화원읍로 다릅니다.
# 27710250 코드는 ad는 설화리, EMD는 화원읍로 다릅니다.
# 27710250 코드는 ad는 명곡리, EMD는 화원읍로 다릅니다.
# 27710250 코드는 ad는 본리리, EMD는 화원읍로 다릅니다.
# 27710253 코드는 ad는 노이리, EMD는 논공읍로 다릅니다.
# 27710253 코드는 ad는 금포리, EMD는 논공읍로 다릅니다.
# 27710253 코드는 ad는 삼리리, EMD는 논공읍로 다릅니다.
# 27710253 코드는 ad는 위천리, EMD는 논공읍로 다릅니다.
# 27710253 코드는 ad는 상리, EMD는 논공읍로 다릅니다.
# 27710253 코드는 ad는 하리, EMD는 논공읍로 다릅니다.
# 27710253 코드는 ad는 남리, EMD는 논공읍로 다릅니다.
# 27710253 코드는 ad는 북리, EMD는 논공읍로 다릅니다.
# 27710253 코드는 ad는 본리리, EMD는 논공읍로 다릅니다.
# 27710256 코드는 ad는 이천리, EMD는 다사읍로 다릅니다.
# 27710256 코드는 ad는 달천리, EMD는 다사읍로 다릅니다.
# 27710256 코드는 ad는 박곡리, EMD는 다사읍로 다릅니다.
# 27710256 코드는 ad는 방천리, EMD는 다사읍로 다릅니다.
# 27710256 코드는 ad는 서재리, EMD는 다사읍로 다릅니다.
# 27710256 코드는 ad는 세천리, EMD는 다사읍로 다릅니다.
# 27710256 코드는 ad는 죽곡리, EMD는 다사읍로 다릅니다.
# 27710256 코드는 ad는 매곡리, EMD는 다사읍로 다릅니다.
# 27710256 코드는 ad는 부곡리, EMD는 다사읍로 다릅니다.
# 27710256 코드는 ad는 문양리, EMD는 다사읍로 다릅니다.
# 27710256 코드는 ad는 문산리, EMD는 다사읍로 다릅니다.
# 27710259 코드는 ad는 음리, EMD는 유가읍로 다릅니다.
# 27710259 코드는 ad는 양리, EMD는 유가읍로 다릅니다.
# 27710259 코드는 ad는 용리, EMD는 유가읍로 다릅니다.
# 27710259 코드는 ad는 봉리, EMD는 유가읍로 다릅니다.
# 27710259 코드는 ad는 쌍계리, EMD는 유가읍로 다릅니다.
# 27710259 코드는 ad는 초곡리, EMD는 유가읍로 다릅니다.
# 27710259 코드는 ad는 상리, EMD는 유가읍로 다릅니다.
# 27710259 코드는 ad는 금리, EMD는 유가읍로 다릅니다.
# 27710259 코드는 ad는 유곡리, EMD는 유가읍로 다릅니다.
# 27710259 코드는 ad는 도의리, EMD는 유가읍로 다릅니다.
# 27710259 코드는 ad는 가태리, EMD는 유가읍로 다릅니다.
# 27710259 코드는 ad는 한정리, EMD는 유가읍로 다릅니다.
# 27710259 코드는 ad는 본말리, EMD는 유가읍로 다릅니다.
# 27710262 코드는 ad는 신당리, EMD는 옥포읍로 다릅니다.
# 27710262 코드는 ad는 교항리, EMD는 옥포읍로 다릅니다.
# 27710262 코드는 ad는 강림리, EMD는 옥포읍로 다릅니다.
# 27710262 코드는 ad는 송촌리, EMD는 옥포읍로 다릅니다.
# 27710262 코드는 ad는 간경리, EMD는 옥포읍로 다릅니다.
# 27710262 코드는 ad는 기세리, EMD는 옥포읍로 다릅니다.
# 27710262 코드는 ad는 반송리, EMD는 옥포읍로 다릅니다.
# 27710262 코드는 ad는 김흥리, EMD는 옥포읍로 다릅니다.
# 27710262 코드는 ad는 본리리, EMD는 옥포읍로 다릅니다.
# 27710265 코드는 ad는 상리, EMD는 현풍읍로 다릅니다.
# 27710265 코드는 ad는 중리, EMD는 현풍읍로 다릅니다.
# 27710265 코드는 ad는 부리, EMD는 현풍읍로 다릅니다.
# 27710265 코드는 ad는 하리, EMD는 현풍읍로 다릅니다.
# 27710265 코드는 ad는 성하리, EMD는 현풍읍로 다릅니다.
# 27710265 코드는 ad는 원교리, EMD는 현풍읍로 다릅니다.
# 27710265 코드는 ad는 자모리, EMD는 현풍읍로 다릅니다.
# 27710265 코드는 ad는 오산리, EMD는 현풍읍로 다릅니다.
# 27710265 코드는 ad는 지리, EMD는 현풍읍로 다릅니다.
# 27710265 코드는 ad는 대리, EMD는 현풍읍로 다릅니다.
# 27710265 코드는 ad는 신기리, EMD는 현풍읍로 다릅니다.
# 27710310 코드는 ad는 용계리, EMD는 가창면로 다릅니다.
# 27710310 코드는 ad는 오리, EMD는 가창면로 다릅니다.
# 27710310 코드는 ad는 정대리, EMD는 가창면로 다릅니다.
# 27710310 코드는 ad는 냉천리, EMD는 가창면로 다릅니다.
# 27710310 코드는 ad는 행정리, EMD는 가창면로 다릅니다.
# 27710310 코드는 ad는 상원리, EMD는 가창면로 다릅니다.
# 27710310 코드는 ad는 단산리, EMD는 가창면로 다릅니다.
# 27710310 코드는 ad는 대일리, EMD는 가창면로 다릅니다.
# 27710310 코드는 ad는 주리, EMD는 가창면로 다릅니다.
# 27710310 코드는 ad는 옥분리, EMD는 가창면로 다릅니다.
# 27710310 코드는 ad는 삼산리, EMD는 가창면로 다릅니다.
# 27710310 코드는 ad는 우록리, EMD는 가창면로 다릅니다.
# 27710330 코드는 ad는 하산리, EMD는 하빈면로 다릅니다.
# 27710330 코드는 ad는 묘리, EMD는 하빈면로 다릅니다.
# 27710330 코드는 ad는 기곡리, EMD는 하빈면로 다릅니다.
# 27710330 코드는 ad는 대평리, EMD는 하빈면로 다릅니다.
# 27710330 코드는 ad는 무등리, EMD는 하빈면로 다릅니다.
# 27710330 코드는 ad는 현내리, EMD는 하빈면로 다릅니다.
# 27710330 코드는 ad는 감문리, EMD는 하빈면로 다릅니다.
# 27710330 코드는 ad는 동곡리, EMD는 하빈면로 다릅니다.
# 27710330 코드는 ad는 봉촌리, EMD는 하빈면로 다릅니다.
# 27710380 코드는 ad는 창리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 응암리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 고봉리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 가천리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 평촌리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 예현리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 유산리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 목단리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 대암리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 내리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 화산리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 수리리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 징리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 오설리, EMD는 구지면로 다릅니다.
# 27710380 코드는 ad는 도동리, EMD는 구지면로 다릅니다.
# 28710250 코드는 ad는 신문리, EMD는 강화읍로 다릅니다.
# 28710250 코드는 ad는 관청리, EMD는 강화읍로 다릅니다.
# 28710250 코드는 ad는 국화리, EMD는 강화읍로 다릅니다.
# 28710250 코드는 ad는 남산리, EMD는 강화읍로 다릅니다.
# 28710250 코드는 ad는 갑곳리, EMD는 강화읍로 다릅니다.
# 28710250 코드는 ad는 용정리, EMD는 강화읍로 다릅니다.
# 28710250 코드는 ad는 옥림리, EMD는 강화읍로 다릅니다.
# 28710250 코드는 ad는 월곳리, EMD는 강화읍로 다릅니다.
# 28710250 코드는 ad는 대산리, EMD는 강화읍로 다릅니다.
# 28710310 코드는 ad는 금월리, EMD는 선원면로 다릅니다.
# 28710310 코드는 ad는 연리, EMD는 선원면로 다릅니다.
# 28710310 코드는 ad는 지산리, EMD는 선원면로 다릅니다.
# 28710310 코드는 ad는 신정리, EMD는 선원면로 다릅니다.
# 28710310 코드는 ad는 창리, EMD는 선원면로 다릅니다.
# 28710310 코드는 ad는 선행리, EMD는 선원면로 다릅니다.
# 28710310 코드는 ad는 냉정리, EMD는 선원면로 다릅니다.
# 28710320 코드는 ad는 두운리, EMD는 불은면로 다릅니다.
# 28710320 코드는 ad는 고능리, EMD는 불은면로 다릅니다.
# 28710320 코드는 ad는 오두리, EMD는 불은면로 다릅니다.
# 28710320 코드는 ad는 넙성리, EMD는 불은면로 다릅니다.
# 28710320 코드는 ad는 신현리, EMD는 불은면로 다릅니다.
# 28710320 코드는 ad는 삼동암리, EMD는 불은면로 다릅니다.
# 28710320 코드는 ad는 삼성리, EMD는 불은면로 다릅니다.
# 28710320 코드는 ad는 덕성리, EMD는 불은면로 다릅니다.
# 28710330 코드는 ad는 온수리, EMD는 길상면로 다릅니다.
# 28710330 코드는 ad는 선두리, EMD는 길상면로 다릅니다.
# 28710330 코드는 ad는 동검리, EMD는 길상면로 다릅니다.
# 28710330 코드는 ad는 초지리, EMD는 길상면로 다릅니다.
# 28710330 코드는 ad는 장흥리, EMD는 길상면로 다릅니다.
# 28710330 코드는 ad는 길직리, EMD는 길상면로 다릅니다.
# 28710340 코드는 ad는 내리, EMD는 화도면로 다릅니다.
# 28710340 코드는 ad는 상방리, EMD는 화도면로 다릅니다.
# 28710340 코드는 ad는 문산리, EMD는 화도면로 다릅니다.
# 28710340 코드는 ad는 덕포리, EMD는 화도면로 다릅니다.
# 28710340 코드는 ad는 사기리, EMD는 화도면로 다릅니다.
# 28710340 코드는 ad는 동막리, EMD는 화도면로 다릅니다.
# 28710340 코드는 ad는 흥왕리, EMD는 화도면로 다릅니다.
# 28710340 코드는 ad는 여차리, EMD는 화도면로 다릅니다.
# 28710340 코드는 ad는 장화리, EMD는 화도면로 다릅니다.
# 28710350 코드는 ad는 하일리, EMD는 양도면로 다릅니다.
# 28710350 코드는 ad는 능내리, EMD는 양도면로 다릅니다.
# 28710350 코드는 ad는 건평리, EMD는 양도면로 다릅니다.
# 28710350 코드는 ad는 인산리, EMD는 양도면로 다릅니다.
# 28710350 코드는 ad는 삼흥리, EMD는 양도면로 다릅니다.
# 28710350 코드는 ad는 길정리, EMD는 양도면로 다릅니다.
# 28710350 코드는 ad는 도장리, EMD는 양도면로 다릅니다.
# 28710350 코드는 ad는 조산리, EMD는 양도면로 다릅니다.
# 28710360 코드는 ad는 고천리, EMD는 내가면로 다릅니다.
# 28710360 코드는 ad는 오상리, EMD는 내가면로 다릅니다.
# 28710360 코드는 ad는 외포리, EMD는 내가면로 다릅니다.
# 28710360 코드는 ad는 황청리, EMD는 내가면로 다릅니다.
# 28710360 코드는 ad는 구하리, EMD는 내가면로 다릅니다.
# 28710370 코드는 ad는 신봉리, EMD는 하점면로 다릅니다.
# 28710370 코드는 ad는 장정리, EMD는 하점면로 다릅니다.
# 28710370 코드는 ad는 부근리, EMD는 하점면로 다릅니다.
# 28710370 코드는 ad는 삼거리, EMD는 하점면로 다릅니다.
# 28710370 코드는 ad는 신삼리, EMD는 하점면로 다릅니다.
# 28710370 코드는 ad는 망월리, EMD는 하점면로 다릅니다.
# 28710370 코드는 ad는 창후리, EMD는 하점면로 다릅니다.
# 28710370 코드는 ad는 이강리, EMD는 하점면로 다릅니다.
# 28710380 코드는 ad는 철산리, EMD는 양사면로 다릅니다.
# 28710380 코드는 ad는 덕하리, EMD는 양사면로 다릅니다.
# 28710380 코드는 ad는 북성리, EMD는 양사면로 다릅니다.
# 28710380 코드는 ad는 교산리, EMD는 양사면로 다릅니다.
# 28710380 코드는 ad는 인화리, EMD는 양사면로 다릅니다.
# 28710390 코드는 ad는 솔정리, EMD는 송해면로 다릅니다.
# 28710390 코드는 ad는 신당리, EMD는 송해면로 다릅니다.
# 28710390 코드는 ad는 숭뢰리, EMD는 송해면로 다릅니다.
# 28710390 코드는 ad는 당산리, EMD는 송해면로 다릅니다.
# 28710390 코드는 ad는 상도리, EMD는 송해면로 다릅니다.
# 28710390 코드는 ad는 하도리, EMD는 송해면로 다릅니다.
# 28710390 코드는 ad는 양오리, EMD는 송해면로 다릅니다.
# 28710400 코드는 ad는 대룡리, EMD는 교동면로 다릅니다.
# 28710400 코드는 ad는 읍내리, EMD는 교동면로 다릅니다.
# 28710400 코드는 ad는 상용리, EMD는 교동면로 다릅니다.
# 28710400 코드는 ad는 봉소리, EMD는 교동면로 다릅니다.
# 28710400 코드는 ad는 고구리, EMD는 교동면로 다릅니다.
# 28710400 코드는 ad는 삼선리, EMD는 교동면로 다릅니다.
# 28710400 코드는 ad는 인사리, EMD는 교동면로 다릅니다.
# 28710400 코드는 ad는 난정리, EMD는 교동면로 다릅니다.
# 28710400 코드는 ad는 양갑리, EMD는 교동면로 다릅니다.
# 28710400 코드는 ad는 동산리, EMD는 교동면로 다릅니다.
# 28710400 코드는 ad는 서한리, EMD는 교동면로 다릅니다.
# 28710400 코드는 ad는 무학리, EMD는 교동면로 다릅니다.
# 28710400 코드는 ad는 지석리, EMD는 교동면로 다릅니다.
# 28710410 코드는 ad는 석모리, EMD는 삼산면로 다릅니다.
# 28710410 코드는 ad는 상리, EMD는 삼산면로 다릅니다.
# 28710410 코드는 ad는 하리, EMD는 삼산면로 다릅니다.
# 28710410 코드는 ad는 석포리, EMD는 삼산면로 다릅니다.
# 28710410 코드는 ad는 매음리, EMD는 삼산면로 다릅니다.
# 28710410 코드는 ad는 서검리, EMD는 삼산면로 다릅니다.
# 28710410 코드는 ad는 미법리, EMD는 삼산면로 다릅니다.
# 28710420 코드는 ad는 주문도리, EMD는 서도면로 다릅니다.
# 28710420 코드는 ad는 아차도리, EMD는 서도면로 다릅니다.
# 28710420 코드는 ad는 말도리, EMD는 서도면로 다릅니다.
# 28710420 코드는 ad는 볼음도리, EMD는 서도면로 다릅니다.
# 28720310 코드는 ad는 시도리, EMD는 북도면로 다릅니다.
# 28720310 코드는 ad는 신도리, EMD는 북도면로 다릅니다.
# 28720310 코드는 ad는 모도리, EMD는 북도면로 다릅니다.
# 28720310 코드는 ad는 장봉리, EMD는 북도면로 다릅니다.
# 28720330 코드는 ad는 진촌리, EMD는 백령면로 다릅니다.
# 28720330 코드는 ad는 북포리, EMD는 백령면로 다릅니다.
# 28720330 코드는 ad는 가을리, EMD는 백령면로 다릅니다.
# 28720330 코드는 ad는 연화리, EMD는 백령면로 다릅니다.
# 28720330 코드는 ad는 남포리, EMD는 백령면로 다릅니다.
# 28720340 코드는 ad는 대청리, EMD는 대청면로 다릅니다.
# 28720340 코드는 ad는 소청리, EMD는 대청면로 다릅니다.
# 28720350 코드는 ad는 북리, EMD는 덕적면로 다릅니다.
# 28720350 코드는 ad는 진리, EMD는 덕적면로 다릅니다.
# 28720350 코드는 ad는 서포리, EMD는 덕적면로 다릅니다.
# 28720350 코드는 ad는 소야리, EMD는 덕적면로 다릅니다.
# 28720350 코드는 ad는 울도리, EMD는 덕적면로 다릅니다.
# 28720350 코드는 ad는 백아리, EMD는 덕적면로 다릅니다.
# 28720350 코드는 ad는 문갑리, EMD는 덕적면로 다릅니다.
# 28720350 코드는 ad는 굴업리, EMD는 덕적면로 다릅니다.
# 28720360 코드는 ad는 외리, EMD는 영흥면로 다릅니다.
# 28720360 코드는 ad는 내리, EMD는 영흥면로 다릅니다.
# 28720360 코드는 ad는 선재리, EMD는 영흥면로 다릅니다.
# 28720370 코드는 ad는 자월리, EMD는 자월면로 다릅니다.
# 28720370 코드는 ad는 이작리, EMD는 자월면로 다릅니다.
# 28720370 코드는 ad는 승봉리, EMD는 자월면로 다릅니다.
# 28720380 코드는 ad는 연평리, EMD는 연평면로 다릅니다.
# 31710250 코드는 ad는 화산리, EMD는 온산읍로 다릅니다.
# 31710250 코드는 ad는 삼평리, EMD는 온산읍로 다릅니다.
# 31710250 코드는 ad는 강양리, EMD는 온산읍로 다릅니다.
# 31710250 코드는 ad는 우봉리, EMD는 온산읍로 다릅니다.
# 31710250 코드는 ad는 당월리, EMD는 온산읍로 다릅니다.
# 31710250 코드는 ad는 처용리, EMD는 온산읍로 다릅니다.
# 31710250 코드는 ad는 산암리, EMD는 온산읍로 다릅니다.
# 31710250 코드는 ad는 대정리, EMD는 온산읍로 다릅니다.
# 31710250 코드는 ad는 방도리, EMD는 온산읍로 다릅니다.
# 31710250 코드는 ad는 이진리, EMD는 온산읍로 다릅니다.
# 31710250 코드는 ad는 원산리, EMD는 온산읍로 다릅니다.
# 31710250 코드는 ad는 덕신리, EMD는 온산읍로 다릅니다.
# 31710250 코드는 ad는 학남리, EMD는 온산읍로 다릅니다.
# 31710253 코드는 ad는 반송리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 반천리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 반곡리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 어음리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 송대리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 평리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 다개리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 대곡리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 직동리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 동부리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 서부리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 남부리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 반연리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 태기리, EMD는 언양읍로 다릅니다.
# 31710253 코드는 ad는 구수리, EMD는 언양읍로 다릅니다.
# 31710256 코드는 ad는 발리, EMD는 온양읍로 다릅니다.
# 31710256 코드는 ad는 대안리, EMD는 온양읍로 다릅니다.
# 31710256 코드는 ad는 망양리, EMD는 온양읍로 다릅니다.
# 31710256 코드는 ad는 남창리, EMD는 온양읍로 다릅니다.
# 31710256 코드는 ad는 동상리, EMD는 온양읍로 다릅니다.
# 31710256 코드는 ad는 삼광리, EMD는 온양읍로 다릅니다.
# 31710256 코드는 ad는 내광리, EMD는 온양읍로 다릅니다.
# 31710256 코드는 ad는 외광리, EMD는 온양읍로 다릅니다.
# 31710256 코드는 ad는 운화리, EMD는 온양읍로 다릅니다.
# 31710256 코드는 ad는 고산리, EMD는 온양읍로 다릅니다.
# 31710259 코드는 ad는 사연리, EMD는 범서읍로 다릅니다.
# 31710259 코드는 ad는 천상리, EMD는 범서읍로 다릅니다.
# 31710259 코드는 ad는 입암리, EMD는 범서읍로 다릅니다.
# 31710259 코드는 ad는 굴화리, EMD는 범서읍로 다릅니다.
# 31710259 코드는 ad는 서사리, EMD는 범서읍로 다릅니다.
# 31710259 코드는 ad는 두산리, EMD는 범서읍로 다릅니다.
# 31710259 코드는 ad는 구영리, EMD는 범서읍로 다릅니다.
# 31710259 코드는 ad는 중리, EMD는 범서읍로 다릅니다.
# 31710259 코드는 ad는 망성리, EMD는 범서읍로 다릅니다.
# 31710259 코드는 ad는 척과리, EMD는 범서읍로 다릅니다.
# 31710262 코드는 ad는 덕하리, EMD는 청량읍로 다릅니다.
# 31710262 코드는 ad는 동천리, EMD는 청량읍로 다릅니다.
# 31710262 코드는 ad는 상남리, EMD는 청량읍로 다릅니다.
# 31710262 코드는 ad는 개곡리, EMD는 청량읍로 다릅니다.
# 31710262 코드는 ad는 중리, EMD는 청량읍로 다릅니다.
# 31710262 코드는 ad는 문죽리, EMD는 청량읍로 다릅니다.
# 31710262 코드는 ad는 삼정리, EMD는 청량읍로 다릅니다.
# 31710262 코드는 ad는 율리, EMD는 청량읍로 다릅니다.
# 31710262 코드는 ad는 용암리, EMD는 청량읍로 다릅니다.
# 31710310 코드는 ad는 신암리, EMD는 서생면로 다릅니다.
# 31710310 코드는 ad는 명산리, EMD는 서생면로 다릅니다.
# 31710310 코드는 ad는 나사리, EMD는 서생면로 다릅니다.
# 31710310 코드는 ad는 화산리, EMD는 서생면로 다릅니다.
# 31710310 코드는 ad는 대송리, EMD는 서생면로 다릅니다.
# 31710310 코드는 ad는 용리, EMD는 서생면로 다릅니다.
# 31710310 코드는 ad는 서생리, EMD는 서생면로 다릅니다.
# 31710310 코드는 ad는 진하리, EMD는 서생면로 다릅니다.
# 31710310 코드는 ad는 화정리, EMD는 서생면로 다릅니다.
# 31710310 코드는 ad는 위양리, EMD는 서생면로 다릅니다.
# 31710340 코드는 ad는 초천리, EMD는 웅촌면로 다릅니다.
# 31710340 코드는 ad는 석천리, EMD는 웅촌면로 다릅니다.
# 31710340 코드는 ad는 곡천리, EMD는 웅촌면로 다릅니다.
# 31710340 코드는 ad는 검단리, EMD는 웅촌면로 다릅니다.
# 31710340 코드는 ad는 은현리, EMD는 웅촌면로 다릅니다.
# 31710340 코드는 ad는 고연리, EMD는 웅촌면로 다릅니다.
# 31710340 코드는 ad는 대대리, EMD는 웅촌면로 다릅니다.
# 31710340 코드는 ad는 통천리, EMD는 웅촌면로 다릅니다.
# 31710340 코드는 ad는 대복리, EMD는 웅촌면로 다릅니다.
# 31710360 코드는 ad는 만화리, EMD는 두동면로 다릅니다.
# 31710360 코드는 ad는 구미리, EMD는 두동면로 다릅니다.
# 31710360 코드는 ad는 월평리, EMD는 두동면로 다릅니다.
# 31710360 코드는 ad는 삼정리, EMD는 두동면로 다릅니다.
# 31710360 코드는 ad는 이전리, EMD는 두동면로 다릅니다.
# 31710360 코드는 ad는 봉계리, EMD는 두동면로 다릅니다.
# 31710360 코드는 ad는 천전리, EMD는 두동면로 다릅니다.
# 31710360 코드는 ad는 은편리, EMD는 두동면로 다릅니다.
# 31710370 코드는 ad는 차리, EMD는 두서면로 다릅니다.
# 31710370 코드는 ad는 구량리, EMD는 두서면로 다릅니다.
# 31710370 코드는 ad는 복안리, EMD는 두서면로 다릅니다.
# 31710370 코드는 ad는 미호리, EMD는 두서면로 다릅니다.
# 31710370 코드는 ad는 활천리, EMD는 두서면로 다릅니다.
# 31710370 코드는 ad는 내와리, EMD는 두서면로 다릅니다.
# 31710370 코드는 ad는 전읍리, EMD는 두서면로 다릅니다.
# 31710370 코드는 ad는 인보리, EMD는 두서면로 다릅니다.
# 31710370 코드는 ad는 서하리, EMD는 두서면로 다릅니다.
# 31710380 코드는 ad는 지내리, EMD는 상북면로 다릅니다.
# 31710380 코드는 ad는 양등리, EMD는 상북면로 다릅니다.
# 31710380 코드는 ad는 산전리, EMD는 상북면로 다릅니다.
# 31710380 코드는 ad는 길천리, EMD는 상북면로 다릅니다.
# 31710380 코드는 ad는 이천리, EMD는 상북면로 다릅니다.
# 31710380 코드는 ad는 덕현리, EMD는 상북면로 다릅니다.
# 31710380 코드는 ad는 명촌리, EMD는 상북면로 다릅니다.
# 31710380 코드는 ad는 천전리, EMD는 상북면로 다릅니다.
# 31710380 코드는 ad는 거리, EMD는 상북면로 다릅니다.
# 31710380 코드는 ad는 궁근정리, EMD는 상북면로 다릅니다.
# 31710380 코드는 ad는 향산리, EMD는 상북면로 다릅니다.
# 31710380 코드는 ad는 소호리, EMD는 상북면로 다릅니다.
# 31710380 코드는 ad는 등억알프스리, EMD는 상북면로 다릅니다.
# 31710390 코드는 ad는 교동리, EMD는 삼남면로 다릅니다.
# 31710390 코드는 ad는 상천리, EMD는 삼남면로 다릅니다.
# 31710390 코드는 ad는 신화리, EMD는 삼남면로 다릅니다.
# 31710390 코드는 ad는 방기리, EMD는 삼남면로 다릅니다.
# 31710390 코드는 ad는 가천리, EMD는 삼남면로 다릅니다.
# 31710400 코드는 ad는 둔기리, EMD는 삼동면로 다릅니다.
# 31710400 코드는 ad는 조일리, EMD는 삼동면로 다릅니다.
# 31710400 코드는 ad는 출강리, EMD는 삼동면로 다릅니다.
# 31710400 코드는 ad는 작동리, EMD는 삼동면로 다릅니다.
# 31710400 코드는 ad는 보은리, EMD는 삼동면로 다릅니다.
# 31710400 코드는 ad는 하잠리, EMD는 삼동면로 다릅니다.
# 31710400 코드는 ad는 금곡리, EMD는 삼동면로 다릅니다.
# 36110250 코드는 ad는 원리, EMD는 조치원읍로 다릅니다.
# 36110250 코드는 ad는 상리, EMD는 조치원읍로 다릅니다.
# 36110250 코드는 ad는 평리, EMD는 조치원읍로 다릅니다.
# 36110250 코드는 ad는 교리, EMD는 조치원읍로 다릅니다.
# 36110250 코드는 ad는 정리, EMD는 조치원읍로 다릅니다.
# 36110250 코드는 ad는 명리, EMD는 조치원읍로 다릅니다.
# 36110250 코드는 ad는 남리, EMD는 조치원읍로 다릅니다.
# 36110250 코드는 ad는 침산리, EMD는 조치원읍로 다릅니다.
# 36110250 코드는 ad는 신흥리, EMD는 조치원읍로 다릅니다.
# 36110250 코드는 ad는 죽림리, EMD는 조치원읍로 다릅니다.
# 36110250 코드는 ad는 번암리, EMD는 조치원읍로 다릅니다.
# 36110250 코드는 ad는 신안리, EMD는 조치원읍로 다릅니다.
# 36110250 코드는 ad는 봉산리, EMD는 조치원읍로 다릅니다.
# 36110250 코드는 ad는 서창리, EMD는 조치원읍로 다릅니다.
# 36110310 코드는 ad는 연기리, EMD는 연기면로 다릅니다.
# 36110310 코드는 ad는 보통리, EMD는 연기면로 다릅니다.
# 36110310 코드는 ad는 눌왕리, EMD는 연기면로 다릅니다.
# 36110310 코드는 ad는 수산리, EMD는 연기면로 다릅니다.
# 36110310 코드는 ad는 세종리, EMD는 연기면로 다릅니다.
# 36110310 코드는 ad는 누리리, EMD는 연기면로 다릅니다.
# 36110310 코드는 ad는 한별리, EMD는 연기면로 다릅니다.
# 36110320 코드는 ad는 내판리, EMD는 연동면로 다릅니다.
# 36110320 코드는 ad는 문주리, EMD는 연동면로 다릅니다.
# 36110320 코드는 ad는 명학리, EMD는 연동면로 다릅니다.
# 36110320 코드는 ad는 응암리, EMD는 연동면로 다릅니다.
# 36110320 코드는 ad는 노송리, EMD는 연동면로 다릅니다.
# 36110320 코드는 ad는 예양리, EMD는 연동면로 다릅니다.
# 36110320 코드는 ad는 송용리, EMD는 연동면로 다릅니다.
# 36110320 코드는 ad는 합강리, EMD는 연동면로 다릅니다.
# 36110320 코드는 ad는 다솜리, EMD는 연동면로 다릅니다.
# 36110320 코드는 ad는 용호리, EMD는 연동면로 다릅니다.
# 36110330 코드는 ad는 부강리, EMD는 부강면로 다릅니다.
# 36110330 코드는 ad는 행산리, EMD는 부강면로 다릅니다.
# 36110330 코드는 ad는 산수리, EMD는 부강면로 다릅니다.
# 36110330 코드는 ad는 갈산리, EMD는 부강면로 다릅니다.
# 36110330 코드는 ad는 문곡리, EMD는 부강면로 다릅니다.
# 36110330 코드는 ad는 등곡리, EMD는 부강면로 다릅니다.
# 36110330 코드는 ad는 노호리, EMD는 부강면로 다릅니다.
# 36110330 코드는 ad는 금호리, EMD는 부강면로 다릅니다.
# 36110340 코드는 ad는 용포리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 발산리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 감성리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 두만리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 용담리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 축산리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 금천리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 영치리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 남곡리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 황용리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 영대리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 달전리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 박산리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 대박리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 부용리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 장재리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 호탄리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 신촌리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 도암리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 성덕리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 영곡리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 성강리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 봉암리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 국곡리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 원봉리, EMD는 금남면로 다릅니다.
# 36110340 코드는 ad는 도남리, EMD는 금남면로 다릅니다.
# 36110350 코드는 ad는 도계리, EMD는 장군면로 다릅니다.
# 36110350 코드는 ad는 평기리, EMD는 장군면로 다릅니다.
# 36110350 코드는 ad는 대교리, EMD는 장군면로 다릅니다.
# 36110350 코드는 ad는 봉안리, EMD는 장군면로 다릅니다.
# 36110350 코드는 ad는 금암리, EMD는 장군면로 다릅니다.
# 36110350 코드는 ad는 하봉리, EMD는 장군면로 다릅니다.
# 36110350 코드는 ad는 은용리, EMD는 장군면로 다릅니다.
# 36110350 코드는 ad는 산학리, EMD는 장군면로 다릅니다.
# 36110350 코드는 ad는 송문리, EMD는 장군면로 다릅니다.
# 36110350 코드는 ad는 송정리, EMD는 장군면로 다릅니다.
# 36110350 코드는 ad는 송학리, EMD는 장군면로 다릅니다.
# 36110350 코드는 ad는 용현리, EMD는 장군면로 다릅니다.
# 36110350 코드는 ad는 용암리, EMD는 장군면로 다릅니다.
# 36110350 코드는 ad는 태산리, EMD는 장군면로 다릅니다.
# 36110360 코드는 ad는 월하리, EMD는 연서면로 다릅니다.
# 36110360 코드는 ad는 쌍전리, EMD는 연서면로 다릅니다.
# 36110360 코드는 ad는 성제리, EMD는 연서면로 다릅니다.
# 36110360 코드는 ad는 고복리, EMD는 연서면로 다릅니다.
# 36110360 코드는 ad는 용암리, EMD는 연서면로 다릅니다.
# 36110360 코드는 ad는 쌍류리, EMD는 연서면로 다릅니다.
# 36110360 코드는 ad는 청라리, EMD는 연서면로 다릅니다.
# 36110360 코드는 ad는 기룡리, EMD는 연서면로 다릅니다.
# 36110360 코드는 ad는 신대리, EMD는 연서면로 다릅니다.
# 36110360 코드는 ad는 국촌리, EMD는 연서면로 다릅니다.
# 36110360 코드는 ad는 와촌리, EMD는 연서면로 다릅니다.
# 36110360 코드는 ad는 부동리, EMD는 연서면로 다릅니다.
# 36110360 코드는 ad는 봉암리, EMD는 연서면로 다릅니다.
# 36110370 코드는 ad는 읍내리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 동교리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 서정리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 원성리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 신흥리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 유천리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 관정리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 신정리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 노곡리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 신방리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 영당리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 양곡리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 달전리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 금사리, EMD는 전의면로 다릅니다.
# 36110370 코드는 ad는 다방리, EMD는 전의면로 다릅니다.
# 36110380 코드는 ad는 노장리, EMD는 전동면로 다릅니다.
# 36110380 코드는 ad는 봉대리, EMD는 전동면로 다릅니다.
# 36110380 코드는 ad는 청송리, EMD는 전동면로 다릅니다.
# 36110380 코드는 ad는 석곡리, EMD는 전동면로 다릅니다.
# 36110380 코드는 ad는 보덕리, EMD는 전동면로 다릅니다.
# 36110380 코드는 ad는 송곡리, EMD는 전동면로 다릅니다.
# 36110380 코드는 ad는 송정리, EMD는 전동면로 다릅니다.
# 36110380 코드는 ad는 청람리, EMD는 전동면로 다릅니다.
# 36110380 코드는 ad는 미곡리, EMD는 전동면로 다릅니다.
# 36110380 코드는 ad는 송성리, EMD는 전동면로 다릅니다.
# 36110380 코드는 ad는 심중리, EMD는 전동면로 다릅니다.
# 36110390 코드는 ad는 소정리, EMD는 소정면로 다릅니다.
# 36110390 코드는 ad는 운당리, EMD는 소정면로 다릅니다.
# 36110390 코드는 ad는 대곡리, EMD는 소정면로 다릅니다.
# 36110390 코드는 ad는 고등리, EMD는 소정면로 다릅니다.
# 36110107 코드는 ad는 합감동, EMD는 나성동로 다릅니다.
# 36110108 코드는 ad는 집현동, EMD는 새롬동로 다릅니다.
# 41220250 코드는 ad는 객사리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 남산리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 추팔리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 노와리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 평궁리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 신궁리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 두리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 신호리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 근내리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 석봉리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 원정리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 도두리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 함정리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 신대리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 본정리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 노양리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 노성리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 두정리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 석근리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 대사리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 안정리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 동창리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 내리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 대추리, EMD는 팽성읍로 다릅니다.
# 41220250 코드는 ad는 송화리, EMD는 팽성읍로 다릅니다.
# 41220253 코드는 ad는 안중리, EMD는 안중읍로 다릅니다.
# 41220253 코드는 ad는 학현리, EMD는 안중읍로 다릅니다.
# 41220253 코드는 ad는 금곡리, EMD는 안중읍로 다릅니다.
# 41220253 코드는 ad는 대반리, EMD는 안중읍로 다릅니다.
# 41220253 코드는 ad는 삼정리, EMD는 안중읍로 다릅니다.
# 41220253 코드는 ad는 용성리, EMD는 안중읍로 다릅니다.
# 41220253 코드는 ad는 덕우리, EMD는 안중읍로 다릅니다.
# 41220253 코드는 ad는 성해리, EMD는 안중읍로 다릅니다.
# 41220253 코드는 ad는 송담리, EMD는 안중읍로 다릅니다.
# 41220253 코드는 ad는 현화리, EMD는 안중읍로 다릅니다.
# 41220256 코드는 ad는 내기리, EMD는 포승읍로 다릅니다.
# 41220256 코드는 ad는 도곡리, EMD는 포승읍로 다릅니다.
# 41220256 코드는 ad는 원정리, EMD는 포승읍로 다릅니다.
# 41220256 코드는 ad는 만호리, EMD는 포승읍로 다릅니다.
# 41220256 코드는 ad는 희곡리, EMD는 포승읍로 다릅니다.
# 41220256 코드는 ad는 신영리, EMD는 포승읍로 다릅니다.
# 41220256 코드는 ad는 방림리, EMD는 포승읍로 다릅니다.
# 41220256 코드는 ad는 석정리, EMD는 포승읍로 다릅니다.
# 41220256 코드는 ad는 홍원리, EMD는 포승읍로 다릅니다.
# 41220310 코드는 ad는 봉남리, EMD는 진위면로 다릅니다.
# 41220310 코드는 ad는 마산리, EMD는 진위면로 다릅니다.
# 41220310 코드는 ad는 은산리, EMD는 진위면로 다릅니다.
# 41220310 코드는 ad는 동천리, EMD는 진위면로 다릅니다.
# 41220310 코드는 ad는 고현리, EMD는 진위면로 다릅니다.
# 41220310 코드는 ad는 청호리, EMD는 진위면로 다릅니다.
# 41220310 코드는 ad는 갈곶리, EMD는 진위면로 다릅니다.
# 41220310 코드는 ad는 야막리, EMD는 진위면로 다릅니다.
# 41220310 코드는 ad는 가곡리, EMD는 진위면로 다릅니다.
# 41220310 코드는 ad는 견산리, EMD는 진위면로 다릅니다.
# 41220310 코드는 ad는 하북리, EMD는 진위면로 다릅니다.
# 41220310 코드는 ad는 신리, EMD는 진위면로 다릅니다.
# 41220320 코드는 ad는 금암리, EMD는 서탄면로 다릅니다.
# 41220320 코드는 ad는 사리, EMD는 서탄면로 다릅니다.
# 41220320 코드는 ad는 수월암리, EMD는 서탄면로 다릅니다.
# 41220320 코드는 ad는 내천리, EMD는 서탄면로 다릅니다.
# 41220320 코드는 ad는 마두리, EMD는 서탄면로 다릅니다.
# 41220320 코드는 ad는 회화리, EMD는 서탄면로 다릅니다.
# 41220320 코드는 ad는 적봉리, EMD는 서탄면로 다릅니다.
# 41220320 코드는 ad는 장등리, EMD는 서탄면로 다릅니다.
# 41220320 코드는 ad는 금각리, EMD는 서탄면로 다릅니다.
# 41220320 코드는 ad는 황구지리, EMD는 서탄면로 다릅니다.
# 41220330 코드는 ad는 당현리, EMD는 고덕면로 다릅니다.
# 41220330 코드는 ad는 두릉리, EMD는 고덕면로 다릅니다.
# 41220330 코드는 ad는 문곡리, EMD는 고덕면로 다릅니다.
# 41220330 코드는 ad는 동청리, EMD는 고덕면로 다릅니다.
# 41220330 코드는 ad는 해창리, EMD는 고덕면로 다릅니다.
# 41220330 코드는 ad는 궁리, EMD는 고덕면로 다릅니다.
# 41220330 코드는 ad는 동고리, EMD는 고덕면로 다릅니다.
# 41220330 코드는 ad는 방축리, EMD는 고덕면로 다릅니다.
# 41220330 코드는 ad는 여염리, EMD는 고덕면로 다릅니다.
# 41220330 코드는 ad는 율포리, EMD는 고덕면로 다릅니다.
# 41220330 코드는 ad는 좌교리, EMD는 고덕면로 다릅니다.
# 41220340 코드는 ad는 숙성리, EMD는 오성면로 다릅니다.
# 41220340 코드는 ad는 교포리, EMD는 오성면로 다릅니다.
# 41220340 코드는 ad는 신리, EMD는 오성면로 다릅니다.
# 41220340 코드는 ad는 안화리, EMD는 오성면로 다릅니다.
# 41220340 코드는 ad는 양교리, EMD는 오성면로 다릅니다.
# 41220340 코드는 ad는 죽리, EMD는 오성면로 다릅니다.
# 41220340 코드는 ad는 길음리, EMD는 오성면로 다릅니다.
# 41220340 코드는 ad는 당거리, EMD는 오성면로 다릅니다.
# 41220340 코드는 ad는 창내리, EMD는 오성면로 다릅니다.
# 41220259 코드는 ad는 현곡리, EMD는 청북읍로 다릅니다.
# 41220259 코드는 ad는 삼계리, EMD는 청북읍로 다릅니다.
# 41220259 코드는 ad는 고잔리, EMD는 청북읍로 다릅니다.
# 41220259 코드는 ad는 옥길리, EMD는 청북읍로 다릅니다.
# 41220259 코드는 ad는 후사리, EMD는 청북읍로 다릅니다.
# 41220259 코드는 ad는 토진리, EMD는 청북읍로 다릅니다.
# 41220259 코드는 ad는 백봉리, EMD는 청북읍로 다릅니다.
# 41220259 코드는 ad는 어연리, EMD는 청북읍로 다릅니다.
# 41220259 코드는 ad는 율북리, EMD는 청북읍로 다릅니다.
# 41220259 코드는 ad는 한산리, EMD는 청북읍로 다릅니다.
# 41220259 코드는 ad는 어소리, EMD는 청북읍로 다릅니다.
# 41220259 코드는 ad는 고렴리, EMD는 청북읍로 다릅니다.
# 41220370 코드는 ad는 도대리, EMD는 현덕면로 다릅니다.
# 41220370 코드는 ad는 운정리, EMD는 현덕면로 다릅니다.
# 41220370 코드는 ad는 화양리, EMD는 현덕면로 다릅니다.
# 41220370 코드는 ad는 황산리, EMD는 현덕면로 다릅니다.
# 41220370 코드는 ad는 인광리, EMD는 현덕면로 다릅니다.
# 41220370 코드는 ad는 덕목리, EMD는 현덕면로 다릅니다.
# 41220370 코드는 ad는 신왕리, EMD는 현덕면로 다릅니다.
# 41220370 코드는 ad는 대안리, EMD는 현덕면로 다릅니다.
# 41220370 코드는 ad는 기산리, EMD는 현덕면로 다릅니다.
# 41220370 코드는 ad는 권관리, EMD는 현덕면로 다릅니다.
# 41220370 코드는 ad는 장수리, EMD는 현덕면로 다릅니다.
# 41220370 코드는 ad는 방축리, EMD는 현덕면로 다릅니다.
# 41360250 코드는 ad는 덕소리, EMD는 와부읍로 다릅니다.
# 41360250 코드는 ad는 도곡리, EMD는 와부읍로 다릅니다.
# 41360250 코드는 ad는 팔당리, EMD는 와부읍로 다릅니다.
# 41360250 코드는 ad는 월문리, EMD는 와부읍로 다릅니다.
# 41360250 코드는 ad는 율석리, EMD는 와부읍로 다릅니다.
# 41360253 코드는 ad는 장현리, EMD는 진접읍로 다릅니다.
# 41360253 코드는 ad는 내각리, EMD는 진접읍로 다릅니다.
# 41360253 코드는 ad는 내곡리, EMD는 진접읍로 다릅니다.
# 41360253 코드는 ad는 연평리, EMD는 진접읍로 다릅니다.
# 41360253 코드는 ad는 부평리, EMD는 진접읍로 다릅니다.
# 41360253 코드는 ad는 팔야리, EMD는 진접읍로 다릅니다.
# 41360253 코드는 ad는 진벌리, EMD는 진접읍로 다릅니다.
# 41360253 코드는 ad는 금곡리, EMD는 진접읍로 다릅니다.
# 41360256 코드는 ad는 마석우리, EMD는 화도읍로 다릅니다.
# 41360256 코드는 ad는 묵현리, EMD는 화도읍로 다릅니다.
# 41360256 코드는 ad는 가곡리, EMD는 화도읍로 다릅니다.
# 41360256 코드는 ad는 구암리, EMD는 화도읍로 다릅니다.
# 41360256 코드는 ad는 금남리, EMD는 화도읍로 다릅니다.
# 41360256 코드는 ad는 답내리, EMD는 화도읍로 다릅니다.
# 41360256 코드는 ad는 월산리, EMD는 화도읍로 다릅니다.
# 41360256 코드는 ad는 창현리, EMD는 화도읍로 다릅니다.
# 41360256 코드는 ad는 녹촌리, EMD는 화도읍로 다릅니다.
# 41360256 코드는 ad는 차산리, EMD는 화도읍로 다릅니다.
# 41360259 코드는 ad는 사능리, EMD는 진건읍로 다릅니다.
# 41360259 코드는 ad는 배양리, EMD는 진건읍로 다릅니다.
# 41360259 코드는 ad는 진관리, EMD는 진건읍로 다릅니다.
# 41360259 코드는 ad는 신월리, EMD는 진건읍로 다릅니다.
# 41360259 코드는 ad는 용정리, EMD는 진건읍로 다릅니다.
# 41360259 코드는 ad는 송능리, EMD는 진건읍로 다릅니다.
# 41360262 코드는 ad는 양지리, EMD는 오남읍로 다릅니다.
# 41360262 코드는 ad는 팔현리, EMD는 오남읍로 다릅니다.
# 41360262 코드는 ad는 오남리, EMD는 오남읍로 다릅니다.
# 41360265 코드는 ad는 퇴계원리, EMD는 퇴계원읍로 다릅니다.
# 41360310 코드는 ad는 청학리, EMD는 별내면로 다릅니다.
# 41360310 코드는 ad는 용암리, EMD는 별내면로 다릅니다.
# 41360310 코드는 ad는 광전리, EMD는 별내면로 다릅니다.
# 41360340 코드는 ad는 운수리, EMD는 수동면로 다릅니다.
# 41360340 코드는 ad는 지둔리, EMD는 수동면로 다릅니다.
# 41360340 코드는 ad는 수산리, EMD는 수동면로 다릅니다.
# 41360340 코드는 ad는 내방리, EMD는 수동면로 다릅니다.
# 41360340 코드는 ad는 외방리, EMD는 수동면로 다릅니다.
# 41360340 코드는 ad는 입석리, EMD는 수동면로 다릅니다.
# 41360340 코드는 ad는 송천리, EMD는 수동면로 다릅니다.
# 41360360 코드는 ad는 능내리, EMD는 조안면로 다릅니다.
# 41360360 코드는 ad는 조안리, EMD는 조안면로 다릅니다.
# 41360360 코드는 ad는 진중리, EMD는 조안면로 다릅니다.
# 41360360 코드는 ad는 송촌리, EMD는 조안면로 다릅니다.
# 41360360 코드는 ad는 삼봉리, EMD는 조안면로 다릅니다.
# 41360360 코드는 ad는 시우리, EMD는 조안면로 다릅니다.
# 41461250 코드는 ad는 삼계리, EMD는 포곡읍로 다릅니다.
# 41461250 코드는 ad는 금어리, EMD는 포곡읍로 다릅니다.
# 41461250 코드는 ad는 둔전리, EMD는 포곡읍로 다릅니다.
# 41461250 코드는 ad는 영문리, EMD는 포곡읍로 다릅니다.
# 41461250 코드는 ad는 마성리, EMD는 포곡읍로 다릅니다.
# 41461250 코드는 ad는 가실리, EMD는 포곡읍로 다릅니다.
# 41461250 코드는 ad는 전대리, EMD는 포곡읍로 다릅니다.
# 41461250 코드는 ad는 유운리, EMD는 포곡읍로 다릅니다.
# 41461250 코드는 ad는 신원리, EMD는 포곡읍로 다릅니다.
# 41461253 코드는 ad는 왕산리, EMD는 모현읍로 다릅니다.
# 41461253 코드는 ad는 갈담리, EMD는 모현읍로 다릅니다.
# 41461253 코드는 ad는 초부리, EMD는 모현읍로 다릅니다.
# 41461253 코드는 ad는 일산리, EMD는 모현읍로 다릅니다.
# 41461253 코드는 ad는 매산리, EMD는 모현읍로 다릅니다.
# 41461253 코드는 ad는 동림리, EMD는 모현읍로 다릅니다.
# 41461253 코드는 ad는 능원리, EMD는 모현읍로 다릅니다.
# 41461253 코드는 ad는 오산리, EMD는 모현읍로 다릅니다.
# 41461320 코드는 ad는 봉무리, EMD는 남사면로 다릅니다.
# 41461320 코드는 ad는 북리, EMD는 남사면로 다릅니다.
# 41461320 코드는 ad는 통삼리, EMD는 남사면로 다릅니다.
# 41461320 코드는 ad는 봉명리, EMD는 남사면로 다릅니다.
# 41461320 코드는 ad는 진목리, EMD는 남사면로 다릅니다.
# 41461320 코드는 ad는 원암리, EMD는 남사면로 다릅니다.
# 41461320 코드는 ad는 전궁리, EMD는 남사면로 다릅니다.
# 41461320 코드는 ad는 방아리, EMD는 남사면로 다릅니다.
# 41461320 코드는 ad는 창리, EMD는 남사면로 다릅니다.
# 41461320 코드는 ad는 아곡리, EMD는 남사면로 다릅니다.
# 41461320 코드는 ad는 완장리, EMD는 남사면로 다릅니다.
# 41461256 코드는 ad는 송전리, EMD는 이동읍로 다릅니다.
# 41461256 코드는 ad는 어비리, EMD는 이동읍로 다릅니다.
# 41461256 코드는 ad는 묘봉리, EMD는 이동읍로 다릅니다.
# 41461256 코드는 ad는 화산리, EMD는 이동읍로 다릅니다.
# 41461256 코드는 ad는 시미리, EMD는 이동읍로 다릅니다.
# 41461256 코드는 ad는 덕성리, EMD는 이동읍로 다릅니다.
# 41461256 코드는 ad는 묵리, EMD는 이동읍로 다릅니다.
# 41461256 코드는 ad는 천리, EMD는 이동읍로 다릅니다.
# 41461256 코드는 ad는 서리, EMD는 이동읍로 다릅니다.
# 41461340 코드는 ad는 고당리, EMD는 원삼면로 다릅니다.
# 41461340 코드는 ad는 사암리, EMD는 원삼면로 다릅니다.
# 41461340 코드는 ad는 좌항리, EMD는 원삼면로 다릅니다.
# 41461340 코드는 ad는 맹리, EMD는 원삼면로 다릅니다.
# 41461340 코드는 ad는 미평리, EMD는 원삼면로 다릅니다.
# 41461340 코드는 ad는 두창리, EMD는 원삼면로 다릅니다.
# 41461340 코드는 ad는 독성리, EMD는 원삼면로 다릅니다.
# 41461340 코드는 ad는 죽능리, EMD는 원삼면로 다릅니다.
# 41461340 코드는 ad는 목신리, EMD는 원삼면로 다릅니다.
# 41461340 코드는 ad는 학일리, EMD는 원삼면로 다릅니다.
# 41461340 코드는 ad는 문촌리, EMD는 원삼면로 다릅니다.
# 41461340 코드는 ad는 가재월리, EMD는 원삼면로 다릅니다.
# 41461350 코드는 ad는 백암리, EMD는 백암면로 다릅니다.
# 41461350 코드는 ad는 박곡리, EMD는 백암면로 다릅니다.
# 41461350 코드는 ad는 백봉리, EMD는 백암면로 다릅니다.
# 41461350 코드는 ad는 고안리, EMD는 백암면로 다릅니다.
# 41461350 코드는 ad는 옥산리, EMD는 백암면로 다릅니다.
# 41461350 코드는 ad는 장평리, EMD는 백암면로 다릅니다.
# 41461350 코드는 ad는 석천리, EMD는 백암면로 다릅니다.
# 41461350 코드는 ad는 용천리, EMD는 백암면로 다릅니다.
# 41461350 코드는 ad는 근삼리, EMD는 백암면로 다릅니다.
# 41461350 코드는 ad는 근창리, EMD는 백암면로 다릅니다.
# 41461350 코드는 ad는 근곡리, EMD는 백암면로 다릅니다.
# 41461350 코드는 ad는 가창리, EMD는 백암면로 다릅니다.
# 41461350 코드는 ad는 가좌리, EMD는 백암면로 다릅니다.
# 41461360 코드는 ad는 양지리, EMD는 양지면로 다릅니다.
# 41461360 코드는 ad는 남곡리, EMD는 양지면로 다릅니다.
# 41461360 코드는 ad는 평창리, EMD는 양지면로 다릅니다.
# 41461360 코드는 ad는 제일리, EMD는 양지면로 다릅니다.
# 41461360 코드는 ad는 추계리, EMD는 양지면로 다릅니다.
# 41461360 코드는 ad는 식금리, EMD는 양지면로 다릅니다.
# 41461360 코드는 ad는 정수리, EMD는 양지면로 다릅니다.
# 41461360 코드는 ad는 대대리, EMD는 양지면로 다릅니다.
# 41461360 코드는 ad는 주북리, EMD는 양지면로 다릅니다.
# 41461360 코드는 ad는 송문리, EMD는 양지면로 다릅니다.
# 41480250 코드는 ad는 문산리, EMD는 문산읍로 다릅니다.
# 41480250 코드는 ad는 당동리, EMD는 문산읍로 다릅니다.
# 41480250 코드는 ad는 선유리, EMD는 문산읍로 다릅니다.
# 41480250 코드는 ad는 임진리, EMD는 문산읍로 다릅니다.
# 41480250 코드는 ad는 운천리, EMD는 문산읍로 다릅니다.
# 41480250 코드는 ad는 사목리, EMD는 문산읍로 다릅니다.
# 41480250 코드는 ad는 마정리, EMD는 문산읍로 다릅니다.
# 41480250 코드는 ad는 장산리, EMD는 문산읍로 다릅니다.
# 41480250 코드는 ad는 내포리, EMD는 문산읍로 다릅니다.
# 41480250 코드는 ad는 이천리, EMD는 문산읍로 다릅니다.
# 41480253 코드는 ad는 봉서리, EMD는 파주읍로 다릅니다.
# 41480253 코드는 ad는 향양리, EMD는 파주읍로 다릅니다.
# 41480253 코드는 ad는 부곡리, EMD는 파주읍로 다릅니다.
# 41480253 코드는 ad는 봉암리, EMD는 파주읍로 다릅니다.
# 41480253 코드는 ad는 백석리, EMD는 파주읍로 다릅니다.
# 41480253 코드는 ad는 파주리, EMD는 파주읍로 다릅니다.
# 41480253 코드는 ad는 연풍리, EMD는 파주읍로 다릅니다.
# 41480256 코드는 ad는 오현리, EMD는 법원읍로 다릅니다.
# 41480256 코드는 ad는 법원리, EMD는 법원읍로 다릅니다.
# 41480256 코드는 ad는 가야리, EMD는 법원읍로 다릅니다.
# 41480256 코드는 ad는 동문리, EMD는 법원읍로 다릅니다.
# 41480256 코드는 ad는 대능리, EMD는 법원읍로 다릅니다.
# 41480256 코드는 ad는 삼방리, EMD는 법원읍로 다릅니다.
# 41480256 코드는 ad는 갈곡리, EMD는 법원읍로 다릅니다.
# 41480256 코드는 ad는 직천리, EMD는 법원읍로 다릅니다.
# 41480256 코드는 ad는 웅담리, EMD는 법원읍로 다릅니다.
# 41480256 코드는 ad는 금곡리, EMD는 법원읍로 다릅니다.
# 41480262 코드는 ad는 봉일천리, EMD는 조리읍로 다릅니다.
# 41480262 코드는 ad는 뇌조리, EMD는 조리읍로 다릅니다.
# 41480262 코드는 ad는 등원리, EMD는 조리읍로 다릅니다.
# 41480262 코드는 ad는 장곡리, EMD는 조리읍로 다릅니다.
# 41480262 코드는 ad는 오산리, EMD는 조리읍로 다릅니다.
# 41480262 코드는 ad는 능안리, EMD는 조리읍로 다릅니다.
# 41480262 코드는 ad는 대원리, EMD는 조리읍로 다릅니다.
# 41480310 코드는 ad는 위전리, EMD는 월롱면로 다릅니다.
# 41480310 코드는 ad는 도내리, EMD는 월롱면로 다릅니다.
# 41480310 코드는 ad는 덕은리, EMD는 월롱면로 다릅니다.
# 41480310 코드는 ad는 능산리, EMD는 월롱면로 다릅니다.
# 41480310 코드는 ad는 영태리, EMD는 월롱면로 다릅니다.
# 41480320 코드는 ad는 성동리, EMD는 탄현면로 다릅니다.
# 41480320 코드는 ad는 법흥리, EMD는 탄현면로 다릅니다.
# 41480320 코드는 ad는 갈현리, EMD는 탄현면로 다릅니다.
# 41480320 코드는 ad는 문지리, EMD는 탄현면로 다릅니다.
# 41480320 코드는 ad는 대동리, EMD는 탄현면로 다릅니다.
# 41480320 코드는 ad는 만우리, EMD는 탄현면로 다릅니다.
# 41480320 코드는 ad는 축현리, EMD는 탄현면로 다릅니다.
# 41480320 코드는 ad는 금승리, EMD는 탄현면로 다릅니다.
# 41480320 코드는 ad는 오금리, EMD는 탄현면로 다릅니다.
# 41480320 코드는 ad는 낙하리, EMD는 탄현면로 다릅니다.
# 41480320 코드는 ad는 금산리, EMD는 탄현면로 다릅니다.
# 41480350 코드는 ad는 분수리, EMD는 광탄면로 다릅니다.
# 41480350 코드는 ad는 방축리, EMD는 광탄면로 다릅니다.
# 41480350 코드는 ad는 마장리, EMD는 광탄면로 다릅니다.
# 41480350 코드는 ad는 발랑리, EMD는 광탄면로 다릅니다.
# 41480350 코드는 ad는 창만리, EMD는 광탄면로 다릅니다.
# 41480350 코드는 ad는 용미리, EMD는 광탄면로 다릅니다.
# 41480350 코드는 ad는 신산리, EMD는 광탄면로 다릅니다.
# 41480350 코드는 ad는 기산리, EMD는 광탄면로 다릅니다.
# 41480350 코드는 ad는 영장리, EMD는 광탄면로 다릅니다.
# 41480360 코드는 ad는 덕천리, EMD는 파평면로 다릅니다.
# 41480360 코드는 ad는 두포리, EMD는 파평면로 다릅니다.
# 41480360 코드는 ad는 마산리, EMD는 파평면로 다릅니다.
# 41480360 코드는 ad는 율곡리, EMD는 파평면로 다릅니다.
# 41480360 코드는 ad는 금파리, EMD는 파평면로 다릅니다.
# 41480360 코드는 ad는 장파리, EMD는 파평면로 다릅니다.
# 41480360 코드는 ad는 눌노리, EMD는 파평면로 다릅니다.
# 41480370 코드는 ad는 어유지리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 장좌리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 장현리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 구읍리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 객현리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 가월리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 무건리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 율포리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 답곡리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 식현리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 주월리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 설마리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 적암리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 두지리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 마지리, EMD는 적성면로 다릅니다.
# 41480370 코드는 ad는 자장리, EMD는 적성면로 다릅니다.
# 41480380 코드는 ad는 백연리, EMD는 군내면로 다릅니다.
# 41480380 코드는 ad는 정자리, EMD는 군내면로 다릅니다.
# 41480380 코드는 ad는 조산리, EMD는 군내면로 다릅니다.
# 41480380 코드는 ad는 읍내리, EMD는 군내면로 다릅니다.
# 41480380 코드는 ad는 송산리, EMD는 군내면로 다릅니다.
# 41480380 코드는 ad는 점원리, EMD는 군내면로 다릅니다.
# 41480380 코드는 ad는 방목리, EMD는 군내면로 다릅니다.
# 41480390 코드는 ad는 노상리, EMD는 장단면로 다릅니다.
# 41480390 코드는 ad는 노하리, EMD는 장단면로 다릅니다.
# 41480390 코드는 ad는 거곡리, EMD는 장단면로 다릅니다.
# 41480390 코드는 ad는 도라산리, EMD는 장단면로 다릅니다.
# 41480390 코드는 ad는 석곶리, EMD는 장단면로 다릅니다.
# 41480390 코드는 ad는 강정리, EMD는 장단면로 다릅니다.
# 41480390 코드는 ad는 동장리, EMD는 장단면로 다릅니다.
# 41480390 코드는 ad는 정동리, EMD는 장단면로 다릅니다.
# 41480400 코드는 ad는 동파리, EMD는 진동면로 다릅니다.
# 41480400 코드는 ad는 용산리, EMD는 진동면로 다릅니다.
# 41480400 코드는 ad는 하포리, EMD는 진동면로 다릅니다.
# 41480400 코드는 ad는 서곡리, EMD는 진동면로 다릅니다.
# 41480400 코드는 ad는 초리, EMD는 진동면로 다릅니다.
# 41480410 코드는 ad는 어룡리, EMD는 진서면로 다릅니다.
# 41480410 코드는 ad는 금릉리, EMD는 진서면로 다릅니다.
# 41500250 코드는 ad는 장호원리, EMD는 장호원읍로 다릅니다.
# 41500250 코드는 ad는 오남리, EMD는 장호원읍로 다릅니다.
# 41500250 코드는 ad는 진암리, EMD는 장호원읍로 다릅니다.
# 41500250 코드는 ad는 어석리, EMD는 장호원읍로 다릅니다.
# 41500250 코드는 ad는 대서리, EMD는 장호원읍로 다릅니다.
# 41500250 코드는 ad는 송산리, EMD는 장호원읍로 다릅니다.
# 41500250 코드는 ad는 방추리, EMD는 장호원읍로 다릅니다.
# 41500250 코드는 ad는 선읍리, EMD는 장호원읍로 다릅니다.
# 41500250 코드는 ad는 이황리, EMD는 장호원읍로 다릅니다.
# 41500250 코드는 ad는 나래리, EMD는 장호원읍로 다릅니다.
# 41500250 코드는 ad는 와현리, EMD는 장호원읍로 다릅니다.
# 41500250 코드는 ad는 풍계리, EMD는 장호원읍로 다릅니다.
# 41500250 코드는 ad는 노탑리, EMD는 장호원읍로 다릅니다.
# 41500253 코드는 ad는 무촌리, EMD는 부발읍로 다릅니다.
# 41500253 코드는 ad는 죽당리, EMD는 부발읍로 다릅니다.
# 41500253 코드는 ad는 신원리, EMD는 부발읍로 다릅니다.
# 41500253 코드는 ad는 고백리, EMD는 부발읍로 다릅니다.
# 41500253 코드는 ad는 대관리, EMD는 부발읍로 다릅니다.
# 41500253 코드는 ad는 마암리, EMD는 부발읍로 다릅니다.
# 41500253 코드는 ad는 산촌리, EMD는 부발읍로 다릅니다.
# 41500253 코드는 ad는 신하리, EMD는 부발읍로 다릅니다.
# 41500253 코드는 ad는 가좌리, EMD는 부발읍로 다릅니다.
# 41500253 코드는 ad는 아미리, EMD는 부발읍로 다릅니다.
# 41500253 코드는 ad는 수정리, EMD는 부발읍로 다릅니다.
# 41500253 코드는 ad는 송온리, EMD는 부발읍로 다릅니다.
# 41500253 코드는 ad는 가산리, EMD는 부발읍로 다릅니다.
# 41500253 코드는 ad는 응암리, EMD는 부발읍로 다릅니다.
# 41500310 코드는 ad는 수광리, EMD는 신둔면로 다릅니다.
# 41500310 코드는 ad는 남정리, EMD는 신둔면로 다릅니다.
# 41500310 코드는 ad는 지석리, EMD는 신둔면로 다릅니다.
# 41500310 코드는 ad는 장동리, EMD는 신둔면로 다릅니다.
# 41500310 코드는 ad는 도봉리, EMD는 신둔면로 다릅니다.
# 41500310 코드는 ad는 도암리, EMD는 신둔면로 다릅니다.
# 41500310 코드는 ad는 수하리, EMD는 신둔면로 다릅니다.
# 41500310 코드는 ad는 수남리, EMD는 신둔면로 다릅니다.
# 41500310 코드는 ad는 고척리, EMD는 신둔면로 다릅니다.
# 41500310 코드는 ad는 용면리, EMD는 신둔면로 다릅니다.
# 41500310 코드는 ad는 인후리, EMD는 신둔면로 다릅니다.
# 41500310 코드는 ad는 마교리, EMD는 신둔면로 다릅니다.
# 41500310 코드는 ad는 소정리, EMD는 신둔면로 다릅니다.
# 41500320 코드는 ad는 현방리, EMD는 백사면로 다릅니다.
# 41500320 코드는 ad는 경사리, EMD는 백사면로 다릅니다.
# 41500320 코드는 ad는 도립리, EMD는 백사면로 다릅니다.
# 41500320 코드는 ad는 송말리, EMD는 백사면로 다릅니다.
# 41500320 코드는 ad는 신대리, EMD는 백사면로 다릅니다.
# 41500320 코드는 ad는 모전리, EMD는 백사면로 다릅니다.
# 41500320 코드는 ad는 도지리, EMD는 백사면로 다릅니다.
# 41500320 코드는 ad는 조읍리, EMD는 백사면로 다릅니다.
# 41500320 코드는 ad는 우곡리, EMD는 백사면로 다릅니다.
# 41500320 코드는 ad는 내촌리, EMD는 백사면로 다릅니다.
# 41500320 코드는 ad는 상용리, EMD는 백사면로 다릅니다.
# 41500320 코드는 ad는 백우리, EMD는 백사면로 다릅니다.
# 41500330 코드는 ad는 유산리, EMD는 호법면로 다릅니다.
# 41500330 코드는 ad는 안평리, EMD는 호법면로 다릅니다.
# 41500330 코드는 ad는 후안리, EMD는 호법면로 다릅니다.
# 41500330 코드는 ad는 단천리, EMD는 호법면로 다릅니다.
# 41500330 코드는 ad는 매곡리, EMD는 호법면로 다릅니다.
# 41500330 코드는 ad는 동산리, EMD는 호법면로 다릅니다.
# 41500330 코드는 ad는 주박리, EMD는 호법면로 다릅니다.
# 41500330 코드는 ad는 주미리, EMD는 호법면로 다릅니다.
# 41500330 코드는 ad는 송갈리, EMD는 호법면로 다릅니다.
# 41500340 코드는 ad는 오천리, EMD는 마장면로 다릅니다.
# 41500340 코드는 ad는 양촌리, EMD는 마장면로 다릅니다.
# 41500340 코드는 ad는 관리, EMD는 마장면로 다릅니다.
# 41500340 코드는 ad는 회억리, EMD는 마장면로 다릅니다.
# 41500340 코드는 ad는 장암리, EMD는 마장면로 다릅니다.
# 41500340 코드는 ad는 목리, EMD는 마장면로 다릅니다.
# 41500340 코드는 ad는 표교리, EMD는 마장면로 다릅니다.
# 41500340 코드는 ad는 이치리, EMD는 마장면로 다릅니다.
# 41500340 코드는 ad는 각평리, EMD는 마장면로 다릅니다.
# 41500340 코드는 ad는 덕평리, EMD는 마장면로 다릅니다.
# 41500340 코드는 ad는 이평리, EMD는 마장면로 다릅니다.
# 41500340 코드는 ad는 해월리, EMD는 마장면로 다릅니다.
# 41500340 코드는 ad는 작촌리, EMD는 마장면로 다릅니다.
# 41500350 코드는 ad는 초지리, EMD는 대월면로 다릅니다.
# 41500350 코드는 ad는 사동리, EMD는 대월면로 다릅니다.
# 41500350 코드는 ad는 대대리, EMD는 대월면로 다릅니다.
# 41500350 코드는 ad는 대흥리, EMD는 대월면로 다릅니다.
# 41500350 코드는 ad는 도리리, EMD는 대월면로 다릅니다.
# 41500350 코드는 ad는 구시리, EMD는 대월면로 다릅니다.
# 41500350 코드는 ad는 군량리, EMD는 대월면로 다릅니다.
# 41500350 코드는 ad는 송라리, EMD는 대월면로 다릅니다.
# 41500350 코드는 ad는 장평리, EMD는 대월면로 다릅니다.
# 41500350 코드는 ad는 부필리, EMD는 대월면로 다릅니다.
# 41500360 코드는 ad는 진가리, EMD는 모가면로 다릅니다.
# 41500360 코드는 ad는 서경리, EMD는 모가면로 다릅니다.
# 41500360 코드는 ad는 산내리, EMD는 모가면로 다릅니다.
# 41500360 코드는 ad는 송곡리, EMD는 모가면로 다릅니다.
# 41500360 코드는 ad는 소사리, EMD는 모가면로 다릅니다.
# 41500360 코드는 ad는 양평리, EMD는 모가면로 다릅니다.
# 41500360 코드는 ad는 원두리, EMD는 모가면로 다릅니다.
# 41500360 코드는 ad는 소고리, EMD는 모가면로 다릅니다.
# 41500360 코드는 ad는 신갈리, EMD는 모가면로 다릅니다.
# 41500360 코드는 ad는 어농리, EMD는 모가면로 다릅니다.
# 41500360 코드는 ad는 두미리, EMD는 모가면로 다릅니다.
# 41500370 코드는 ad는 금당리, EMD는 설성면로 다릅니다.
# 41500370 코드는 ad는 장능리, EMD는 설성면로 다릅니다.
# 41500370 코드는 ad는 행죽리, EMD는 설성면로 다릅니다.
# 41500370 코드는 ad는 제요리, EMD는 설성면로 다릅니다.
# 41500370 코드는 ad는 신필리, EMD는 설성면로 다릅니다.
# 41500370 코드는 ad는 장천리, EMD는 설성면로 다릅니다.
# 41500370 코드는 ad는 자석리, EMD는 설성면로 다릅니다.
# 41500370 코드는 ad는 암산리, EMD는 설성면로 다릅니다.
# 41500370 코드는 ad는 송계리, EMD는 설성면로 다릅니다.
# 41500370 코드는 ad는 상봉리, EMD는 설성면로 다릅니다.
# 41500370 코드는 ad는 수산리, EMD는 설성면로 다릅니다.
# 41500370 코드는 ad는 대죽리, EMD는 설성면로 다릅니다.
# 41500380 코드는 ad는 고당리, EMD는 율면로 다릅니다.
# 41500380 코드는 ad는 신추리, EMD는 율면로 다릅니다.
# 41500380 코드는 ad는 본죽리, EMD는 율면로 다릅니다.
# 41500380 코드는 ad는 북두리, EMD는 율면로 다릅니다.
# 41500380 코드는 ad는 산양리, EMD는 율면로 다릅니다.
# 41500380 코드는 ad는 석산리, EMD는 율면로 다릅니다.
# 41500380 코드는 ad는 산성리, EMD는 율면로 다릅니다.
# 41500380 코드는 ad는 오성리, EMD는 율면로 다릅니다.
# 41500380 코드는 ad는 월포리, EMD는 율면로 다릅니다.
# 41500380 코드는 ad는 총곡리, EMD는 율면로 다릅니다.
# 41550250 코드는 ad는 양기리, EMD는 공도읍로 다릅니다.
# 41550250 코드는 ad는 웅교리, EMD는 공도읍로 다릅니다.
# 41550250 코드는 ad는 신두리, EMD는 공도읍로 다릅니다.
# 41550250 코드는 ad는 중복리, EMD는 공도읍로 다릅니다.
# 41550250 코드는 ad는 용두리, EMD는 공도읍로 다릅니다.
# 41550250 코드는 ad는 승두리, EMD는 공도읍로 다릅니다.
# 41550250 코드는 ad는 건천리, EMD는 공도읍로 다릅니다.
# 41550250 코드는 ad는 불당리, EMD는 공도읍로 다릅니다.
# 41550250 코드는 ad는 만정리, EMD는 공도읍로 다릅니다.
# 41550250 코드는 ad는 마정리, EMD는 공도읍로 다릅니다.
# 41550250 코드는 ad는 진사리, EMD는 공도읍로 다릅니다.
# 41550310 코드는 ad는 적가리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 기좌리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 북좌리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 상삼리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 신장리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 양복리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 오두리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 이전리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 불현리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 내방리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 동신리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 곡천리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 복평리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 구사리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 가율리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 신안리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 동평리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 남풍리, EMD는 보개면로 다릅니다.
# 41550310 코드는 ad는 북가현리, EMD는 보개면로 다릅니다.
# 41550320 코드는 ad는 내우리, EMD는 금광면로 다릅니다.
# 41550320 코드는 ad는 개산리, EMD는 금광면로 다릅니다.
# 41550320 코드는 ad는 장죽리, EMD는 금광면로 다릅니다.
# 41550320 코드는 ad는 상중리, EMD는 금광면로 다릅니다.
# 41550320 코드는 ad는 금광리, EMD는 금광면로 다릅니다.
# 41550320 코드는 ad는 현곡리, EMD는 금광면로 다릅니다.
# 41550320 코드는 ad는 삼흥리, EMD는 금광면로 다릅니다.
# 41550320 코드는 ad는 사흥리, EMD는 금광면로 다릅니다.
# 41550320 코드는 ad는 오흥리, EMD는 금광면로 다릅니다.
# 41550320 코드는 ad는 한운리, EMD는 금광면로 다릅니다.
# 41550320 코드는 ad는 오산리, EMD는 금광면로 다릅니다.
# 41550320 코드는 ad는 옥정리, EMD는 금광면로 다릅니다.
# 41550320 코드는 ad는 석하리, EMD는 금광면로 다릅니다.
# 41550320 코드는 ad는 신양복리, EMD는 금광면로 다릅니다.
# 41550330 코드는 ad는 인리, EMD는 서운면로 다릅니다.
# 41550330 코드는 ad는 청용리, EMD는 서운면로 다릅니다.
# 41550330 코드는 ad는 송정리, EMD는 서운면로 다릅니다.
# 41550330 코드는 ad는 신촌리, EMD는 서운면로 다릅니다.
# 41550330 코드는 ad는 산평리, EMD는 서운면로 다릅니다.
# 41550330 코드는 ad는 현매리, EMD는 서운면로 다릅니다.
# 41550330 코드는 ad는 동촌리, EMD는 서운면로 다릅니다.
# 41550330 코드는 ad는 신흥리, EMD는 서운면로 다릅니다.
# 41550330 코드는 ad는 신능리, EMD는 서운면로 다릅니다.
# 41550330 코드는 ad는 신기리, EMD는 서운면로 다릅니다.
# 41550330 코드는 ad는 송산리, EMD는 서운면로 다릅니다.
# 41550330 코드는 ad는 오촌리, EMD는 서운면로 다릅니다.
# 41550330 코드는 ad는 양촌리, EMD는 서운면로 다릅니다.
# 41550330 코드는 ad는 북산리, EMD는 서운면로 다릅니다.
# 41550340 코드는 ad는 구례리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 계륵리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 개정리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 신계리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 법전리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 용두리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 고지리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 정동리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 구수리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 진촌리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 갈전리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 양지리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 보체리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 신기리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 강덕리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 후평리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 마산리, EMD는 미양면로 다릅니다.
# 41550340 코드는 ad는 양변리, EMD는 미양면로 다릅니다.
# 41550350 코드는 ad는 소현리, EMD는 대덕면로 다릅니다.
# 41550350 코드는 ad는 토현리, EMD는 대덕면로 다릅니다.
# 41550350 코드는 ad는 모산리, EMD는 대덕면로 다릅니다.
# 41550350 코드는 ad는 보동리, EMD는 대덕면로 다릅니다.
# 41550350 코드는 ad는 명당리, EMD는 대덕면로 다릅니다.
# 41550350 코드는 ad는 진현리, EMD는 대덕면로 다릅니다.
# 41550350 코드는 ad는 건지리, EMD는 대덕면로 다릅니다.
# 41550350 코드는 ad는 내리, EMD는 대덕면로 다릅니다.
# 41550350 코드는 ad는 대농리, EMD는 대덕면로 다릅니다.
# 41550350 코드는 ad는 죽리, EMD는 대덕면로 다릅니다.
# 41550350 코드는 ad는 신령리, EMD는 대덕면로 다릅니다.
# 41550350 코드는 ad는 무능리, EMD는 대덕면로 다릅니다.
# 41550350 코드는 ad는 소내리, EMD는 대덕면로 다릅니다.
# 41550350 코드는 ad는 삼한리, EMD는 대덕면로 다릅니다.
# 41550360 코드는 ad는 동항리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 구장리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 석화리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 추곡리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 조일리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 도곡리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 산정리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 이현리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 장서리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 난실리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 노곡리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 미산리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 방축리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 필산리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 덕봉리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 명목리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 삼암리, EMD는 양성면로 다릅니다.
# 41550360 코드는 ad는 방신리, EMD는 양성면로 다릅니다.
# 41550380 코드는 ad는 성은리, EMD는 원곡면로 다릅니다.
# 41550380 코드는 ad는 칠곡리, EMD는 원곡면로 다릅니다.
# 41550380 코드는 ad는 지문리, EMD는 원곡면로 다릅니다.
# 41550380 코드는 ad는 산하리, EMD는 원곡면로 다릅니다.
# 41550380 코드는 ad는 내가천리, EMD는 원곡면로 다릅니다.
# 41550380 코드는 ad는 외가천리, EMD는 원곡면로 다릅니다.
# 41550380 코드는 ad는 반제리, EMD는 원곡면로 다릅니다.
# 41550380 코드는 ad는 성주리, EMD는 원곡면로 다릅니다.
# 41550390 코드는 ad는 월정리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 주천리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 죽림리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 가리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 산북리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 당촌리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 방초리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 송천리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 고은리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 화곡리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 능국리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 신흥리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 금산리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 장암리, EMD는 일죽면로 다릅니다.
# 41550390 코드는 ad는 화봉리, EMD는 일죽면로 다릅니다.
# 41550400 코드는 ad는 죽산리, EMD는 죽산면로 다릅니다.
# 41550400 코드는 ad는 매산리, EMD는 죽산면로 다릅니다.
# 41550400 코드는 ad는 장원리, EMD는 죽산면로 다릅니다.
# 41550400 코드는 ad는 두현리, EMD는 죽산면로 다릅니다.
# 41550400 코드는 ad는 장능리, EMD는 죽산면로 다릅니다.
# 41550400 코드는 ad는 장계리, EMD는 죽산면로 다릅니다.
# 41550400 코드는 ad는 용설리, EMD는 죽산면로 다릅니다.
# 41550400 코드는 ad는 칠장리, EMD는 죽산면로 다릅니다.
# 41550400 코드는 ad는 당목리, EMD는 죽산면로 다릅니다.
# 41550400 코드는 ad는 두교리, EMD는 죽산면로 다릅니다.
# 41550410 코드는 ad는 내장리, EMD는 삼죽면로 다릅니다.
# 41550410 코드는 ad는 율곡리, EMD는 삼죽면로 다릅니다.
# 41550410 코드는 ad는 용월리, EMD는 삼죽면로 다릅니다.
# 41550410 코드는 ad는 덕산리, EMD는 삼죽면로 다릅니다.
# 41550410 코드는 ad는 배태리, EMD는 삼죽면로 다릅니다.
# 41550410 코드는 ad는 내강리, EMD는 삼죽면로 다릅니다.
# 41550410 코드는 ad는 진촌리, EMD는 삼죽면로 다릅니다.
# 41550410 코드는 ad는 미장리, EMD는 삼죽면로 다릅니다.
# 41550410 코드는 ad는 마전리, EMD는 삼죽면로 다릅니다.
# 41550410 코드는 ad는 기솔리, EMD는 삼죽면로 다릅니다.
# 41550420 코드는 ad는 쌍지리, EMD는 고삼면로 다릅니다.
# 41550420 코드는 ad는 신창리, EMD는 고삼면로 다릅니다.
# 41550420 코드는 ad는 대갈리, EMD는 고삼면로 다릅니다.
# 41550420 코드는 ad는 가유리, EMD는 고삼면로 다릅니다.
# 41550420 코드는 ad는 삼은리, EMD는 고삼면로 다릅니다.
# 41550420 코드는 ad는 봉산리, EMD는 고삼면로 다릅니다.
# 41550420 코드는 ad는 월향리, EMD는 고삼면로 다릅니다.
# 41570250 코드는 ad는 도사리, EMD는 통진읍로 다릅니다.
# 41570250 코드는 ad는 마송리, EMD는 통진읍로 다릅니다.
# 41570250 코드는 ad는 서암리, EMD는 통진읍로 다릅니다.
# 41570250 코드는 ad는 수참리, EMD는 통진읍로 다릅니다.
# 41570250 코드는 ad는 가현리, EMD는 통진읍로 다릅니다.
# 41570250 코드는 ad는 동을산리, EMD는 통진읍로 다릅니다.
# 41570250 코드는 ad는 귀전리, EMD는 통진읍로 다릅니다.
# 41570250 코드는 ad는 고정리, EMD는 통진읍로 다릅니다.
# 41570250 코드는 ad는 옹정리, EMD는 통진읍로 다릅니다.
# 41570253 코드는 ad는 향산리, EMD는 고촌읍로 다릅니다.
# 41570253 코드는 ad는 풍곡리, EMD는 고촌읍로 다릅니다.
# 41570253 코드는 ad는 태리, EMD는 고촌읍로 다릅니다.
# 41570253 코드는 ad는 신곡리, EMD는 고촌읍로 다릅니다.
# 41570253 코드는 ad는 전호리, EMD는 고촌읍로 다릅니다.
# 41570256 코드는 ad는 양곡리, EMD는 양촌읍로 다릅니다.
# 41570256 코드는 ad는 누산리, EMD는 양촌읍로 다릅니다.
# 41570256 코드는 ad는 석모리, EMD는 양촌읍로 다릅니다.
# 41570256 코드는 ad는 구래리, EMD는 양촌읍로 다릅니다.
# 41570256 코드는 ad는 대포리, EMD는 양촌읍로 다릅니다.
# 41570256 코드는 ad는 학운리, EMD는 양촌읍로 다릅니다.
# 41570256 코드는 ad는 유현리, EMD는 양촌읍로 다릅니다.
# 41570256 코드는 ad는 흥신리, EMD는 양촌읍로 다릅니다.
# 41570340 코드는 ad는 대능리, EMD는 대곶면로 다릅니다.
# 41570340 코드는 ad는 대벽리, EMD는 대곶면로 다릅니다.
# 41570340 코드는 ad는 약암리, EMD는 대곶면로 다릅니다.
# 41570340 코드는 ad는 상마리, EMD는 대곶면로 다릅니다.
# 41570340 코드는 ad는 율생리, EMD는 대곶면로 다릅니다.
# 41570340 코드는 ad는 초원지리, EMD는 대곶면로 다릅니다.
# 41570340 코드는 ad는 거물대리, EMD는 대곶면로 다릅니다.
# 41570340 코드는 ad는 오니산리, EMD는 대곶면로 다릅니다.
# 41570340 코드는 ad는 송마리, EMD는 대곶면로 다릅니다.
# 41570340 코드는 ad는 석정리, EMD는 대곶면로 다릅니다.
# 41570340 코드는 ad는 쇄암리, EMD는 대곶면로 다릅니다.
# 41570340 코드는 ad는 신안리, EMD는 대곶면로 다릅니다.
# 41570340 코드는 ad는 대명리, EMD는 대곶면로 다릅니다.
# 41570350 코드는 ad는 군하리, EMD는 월곶면로 다릅니다.
# 41570350 코드는 ad는 고막리, EMD는 월곶면로 다릅니다.
# 41570350 코드는 ad는 갈산리, EMD는 월곶면로 다릅니다.
# 41570350 코드는 ad는 고양리, EMD는 월곶면로 다릅니다.
# 41570350 코드는 ad는 포내리, EMD는 월곶면로 다릅니다.
# 41570350 코드는 ad는 성동리, EMD는 월곶면로 다릅니다.
# 41570350 코드는 ad는 보구곶리, EMD는 월곶면로 다릅니다.
# 41570350 코드는 ad는 용강리, EMD는 월곶면로 다릅니다.
# 41570350 코드는 ad는 조강리, EMD는 월곶면로 다릅니다.
# 41570350 코드는 ad는 개곡리, EMD는 월곶면로 다릅니다.
# 41570360 코드는 ad는 마곡리, EMD는 하성면로 다릅니다.
# 41570360 코드는 ad는 석탄리, EMD는 하성면로 다릅니다.
# 41570360 코드는 ad는 후평리, EMD는 하성면로 다릅니다.
# 41570360 코드는 ad는 시암리, EMD는 하성면로 다릅니다.
# 41570360 코드는 ad는 마조리, EMD는 하성면로 다릅니다.
# 41570360 코드는 ad는 가금리, EMD는 하성면로 다릅니다.
# 41570360 코드는 ad는 양택리, EMD는 하성면로 다릅니다.
# 41570360 코드는 ad는 원산리, EMD는 하성면로 다릅니다.
# 41570360 코드는 ad는 하사리, EMD는 하성면로 다릅니다.
# 41570360 코드는 ad는 봉성리, EMD는 하성면로 다릅니다.
# 41570360 코드는 ad는 전류리, EMD는 하성면로 다릅니다.
# 41570360 코드는 ad는 마근포리, EMD는 하성면로 다릅니다.
# 41590253 코드는 ad는 상리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 내리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 수영리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 동화리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 와우리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 수기리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 분천리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 왕림리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 세곡리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 당하리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 마하리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 유리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 덕리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 덕우리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 하가등리, EMD는 봉담읍로 다릅니다.
# 41590253 코드는 ad는 상기리, EMD는 봉담읍로 다릅니다.
# 41590256 코드는 ad는 원안리, EMD는 우정읍로 다릅니다.
# 41590256 코드는 ad는 호곡리, EMD는 우정읍로 다릅니다.
# 41590256 코드는 ad는 운평리, EMD는 우정읍로 다릅니다.
# 41590256 코드는 ad는 한각리, EMD는 우정읍로 다릅니다.
# 41590256 코드는 ad는 멱우리, EMD는 우정읍로 다릅니다.
# 41590256 코드는 ad는 화수리, EMD는 우정읍로 다릅니다.
# 41590256 코드는 ad는 주곡리, EMD는 우정읍로 다릅니다.
# 41590256 코드는 ad는 이화리, EMD는 우정읍로 다릅니다.
# 41590256 코드는 ad는 석천리, EMD는 우정읍로 다릅니다.
# 41590256 코드는 ad는 매향리, EMD는 우정읍로 다릅니다.
# 41590256 코드는 ad는 화산리, EMD는 우정읍로 다릅니다.
# 41590256 코드는 ad는 조암리, EMD는 우정읍로 다릅니다.
# 41590256 코드는 ad는 국화리, EMD는 우정읍로 다릅니다.
# 41590259 코드는 ad는 평리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 발안리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 제암리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 상신리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 구문천리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 하길리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 화리현리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 상두리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 백토리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 길성리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 요리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 수직리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 갈천리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 증거리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 송곡리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 동오리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 관리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 도이리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 행정리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 방축리, EMD는 향남읍로 다릅니다.
# 41590259 코드는 ad는 장짐리, EMD는 향남읍로 다릅니다.
# 41590262 코드는 ad는 남양리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 신남리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 장덕리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 안석리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 활초리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 온석리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 무송리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 북양리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 송림리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 수화리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 장전리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 신외리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 문호리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 시리, EMD는 남양읍로 다릅니다.
# 41590262 코드는 ad는 원천리, EMD는 남양읍로 다릅니다.
# 41590310 코드는 ad는 천천리, EMD는 매송면로 다릅니다.
# 41590310 코드는 ad는 원평리, EMD는 매송면로 다릅니다.
# 41590310 코드는 ad는 어천리, EMD는 매송면로 다릅니다.
# 41590310 코드는 ad는 숙곡리, EMD는 매송면로 다릅니다.
# 41590310 코드는 ad는 야목리, EMD는 매송면로 다릅니다.
# 41590310 코드는 ad는 송라리, EMD는 매송면로 다릅니다.
# 41590310 코드는 ad는 원리, EMD는 매송면로 다릅니다.
# 41590320 코드는 ad는 양노리, EMD는 비봉면로 다릅니다.
# 41590320 코드는 ad는 남전리, EMD는 비봉면로 다릅니다.
# 41590320 코드는 ad는 유포리, EMD는 비봉면로 다릅니다.
# 41590320 코드는 ad는 삼화리, EMD는 비봉면로 다릅니다.
# ...
# 48880250 코드는 ad는 상림리, EMD는 거창읍로 다릅니다.
# 48880250 코드는 ad는 중앙리, EMD는 거창읍로 다릅니다.
# 48880250 코드는 ad는 대동리, EMD는 거창읍로 다릅니다.
# 48880250 코드는 ad는 대평리, EMD는 거창읍로 다릅니다.
# 48880250 코드는 ad는 김천리, EMD는 거창읍로 다릅니다.
# 48880250 코드는 ad는 송정리, EMD는 거창읍로 다릅니다.
# 48880250 코드는 ad는 장팔리, EMD는 거창읍로 다릅니다.
# 48880250 코드는 ad는 정장리, EMD는 거창읍로 다릅니다.
# 48880250 코드는 ad는 동변리, EMD는 거창읍로 다릅니다.
# 48880250 코드는 ad는 서변리, EMD는 거창읍로 다릅니다.
# 48880250 코드는 ad는 가지리, EMD는 거창읍로 다릅니다.
# 48880250 코드는 ad는 양평리, EMD는 거창읍로 다릅니다.
# 48880250 코드는 ad는 학리, EMD는 거창읍로 다릅니다.
# 48880310 코드는 ad는 성기리, EMD는 주상면로 다릅니다.
# 48880310 코드는 ad는 남산리, EMD는 주상면로 다릅니다.
# 48880310 코드는 ad는 거기리, EMD는 주상면로 다릅니다.
# 48880310 코드는 ad는 도평리, EMD는 주상면로 다릅니다.
# 48880310 코드는 ad는 연교리, EMD는 주상면로 다릅니다.
# 48880310 코드는 ad는 완대리, EMD는 주상면로 다릅니다.
# 48880310 코드는 ad는 내오리, EMD는 주상면로 다릅니다.
# 48880320 코드는 ad는 신촌리, EMD는 웅양면로 다릅니다.
# 48880320 코드는 ad는 한기리, EMD는 웅양면로 다릅니다.
# 48880320 코드는 ad는 죽림리, EMD는 웅양면로 다릅니다.
# 48880320 코드는 ad는 군암리, EMD는 웅양면로 다릅니다.
# 48880320 코드는 ad는 동호리, EMD는 웅양면로 다릅니다.
# 48880320 코드는 ad는 산포리, EMD는 웅양면로 다릅니다.
# 48880320 코드는 ad는 노현리, EMD는 웅양면로 다릅니다.
# 48880330 코드는 ad는 개명리, EMD는 고제면로 다릅니다.
# 48880330 코드는 ad는 봉산리, EMD는 고제면로 다릅니다.
# 48880330 코드는 ad는 봉계리, EMD는 고제면로 다릅니다.
# 48880330 코드는 ad는 농산리, EMD는 고제면로 다릅니다.
# 48880330 코드는 ad는 궁항리, EMD는 고제면로 다릅니다.
# 48880340 코드는 ad는 병곡리, EMD는 북상면로 다릅니다.
# 48880340 코드는 ad는 갈계리, EMD는 북상면로 다릅니다.
# 48880340 코드는 ad는 농산리, EMD는 북상면로 다릅니다.
# 48880340 코드는 ad는 월성리, EMD는 북상면로 다릅니다.
# 48880340 코드는 ad는 소정리, EMD는 북상면로 다릅니다.
# 48880340 코드는 ad는 산수리, EMD는 북상면로 다릅니다.
# 48880340 코드는 ad는 창선리, EMD는 북상면로 다릅니다.
# 48880350 코드는 ad는 장기리, EMD는 위천면로 다릅니다.
# 48880350 코드는 ad는 남산리, EMD는 위천면로 다릅니다.
# 48880350 코드는 ad는 상천리, EMD는 위천면로 다릅니다.
# 48880350 코드는 ad는 당산리, EMD는 위천면로 다릅니다.
# 48880350 코드는 ad는 강천리, EMD는 위천면로 다릅니다.
# 48880350 코드는 ad는 모동리, EMD는 위천면로 다릅니다.
# 48880350 코드는 ad는 황산리, EMD는 위천면로 다릅니다.
# 48880360 코드는 ad는 말흘리, EMD는 마리면로 다릅니다.
# 48880360 코드는 ad는 영승리, EMD는 마리면로 다릅니다.
# 48880360 코드는 ad는 고학리, EMD는 마리면로 다릅니다.
# 48880360 코드는 ad는 율리, EMD는 마리면로 다릅니다.
# 48880360 코드는 ad는 대동리, EMD는 마리면로 다릅니다.
# 48880360 코드는 ad는 하고리, EMD는 마리면로 다릅니다.
# 48880360 코드는 ad는 월계리, EMD는 마리면로 다릅니다.
# 48880370 코드는 ad는 무촌리, EMD는 남상면로 다릅니다.
# 48880370 코드는 ad는 대산리, EMD는 남상면로 다릅니다.
# 48880370 코드는 ad는 둔동리, EMD는 남상면로 다릅니다.
# 48880370 코드는 ad는 월평리, EMD는 남상면로 다릅니다.
# 48880370 코드는 ad는 송변리, EMD는 남상면로 다릅니다.
# 48880370 코드는 ad는 전척리, EMD는 남상면로 다릅니다.
# 48880370 코드는 ad는 오계리, EMD는 남상면로 다릅니다.
# 48880370 코드는 ad는 임불리, EMD는 남상면로 다릅니다.
# 48880370 코드는 ad는 춘전리, EMD는 남상면로 다릅니다.
# 48880370 코드는 ad는 진목리, EMD는 남상면로 다릅니다.
# 48880380 코드는 ad는 무릉리, EMD는 남하면로 다릅니다.
# 48880380 코드는 ad는 양항리, EMD는 남하면로 다릅니다.
# 48880380 코드는 ad는 둔마리, EMD는 남하면로 다릅니다.
# 48880380 코드는 ad는 지산리, EMD는 남하면로 다릅니다.
# 48880380 코드는 ad는 대야리, EMD는 남하면로 다릅니다.
# 48880390 코드는 ad는 수원리, EMD는 신원면로 다릅니다.
# 48880390 코드는 ad는 와룡리, EMD는 신원면로 다릅니다.
# 48880390 코드는 ad는 청수리, EMD는 신원면로 다릅니다.
# 48880390 코드는 ad는 대현리, EMD는 신원면로 다릅니다.
# 48880390 코드는 ad는 구사리, EMD는 신원면로 다릅니다.
# 48880390 코드는 ad는 과정리, EMD는 신원면로 다릅니다.
# 48880390 코드는 ad는 양지리, EMD는 신원면로 다릅니다.
# 48880390 코드는 ad는 덕산리, EMD는 신원면로 다릅니다.
# 48880390 코드는 ad는 중유리, EMD는 신원면로 다릅니다.
# 48880400 코드는 ad는 대초리, EMD는 가조면로 다릅니다.
# 48880400 코드는 ad는 기리, EMD는 가조면로 다릅니다.
# 48880400 코드는 ad는 석강리, EMD는 가조면로 다릅니다.
# 48880400 코드는 ad는 사병리, EMD는 가조면로 다릅니다.
# 48880400 코드는 ad는 일부리, EMD는 가조면로 다릅니다.
# 48880400 코드는 ad는 도리, EMD는 가조면로 다릅니다.
# 48880400 코드는 ad는 장기리, EMD는 가조면로 다릅니다.
# 48880400 코드는 ad는 마상리, EMD는 가조면로 다릅니다.
# 48880400 코드는 ad는 수월리, EMD는 가조면로 다릅니다.
# 48880400 코드는 ad는 동례리, EMD는 가조면로 다릅니다.
# 48880410 코드는 ad는 용산리, EMD는 가북면로 다릅니다.
# 48880410 코드는 ad는 우혜리, EMD는 가북면로 다릅니다.
# 48880410 코드는 ad는 중촌리, EMD는 가북면로 다릅니다.
# 48880410 코드는 ad는 해평리, EMD는 가북면로 다릅니다.
# 48880410 코드는 ad는 용암리, EMD는 가북면로 다릅니다.
# 48880410 코드는 ad는 몽석리, EMD는 가북면로 다릅니다.
# 48880410 코드는 ad는 박암리, EMD는 가북면로 다릅니다.
# 48890250 코드는 ad는 합천리, EMD는 합천읍로 다릅니다.
# 48890250 코드는 ad는 금양리, EMD는 합천읍로 다릅니다.
# 48890250 코드는 ad는 영창리, EMD는 합천읍로 다릅니다.
# 48890250 코드는 ad는 내곡리, EMD는 합천읍로 다릅니다.
# 48890250 코드는 ad는 서산리, EMD는 합천읍로 다릅니다.
# 48890250 코드는 ad는 용계리, EMD는 합천읍로 다릅니다.
# 48890250 코드는 ad는 외곡리, EMD는 합천읍로 다릅니다.
# 48890250 코드는 ad는 장계리, EMD는 합천읍로 다릅니다.
# 48890250 코드는 ad는 인곡리, EMD는 합천읍로 다릅니다.
# 48890310 코드는 ad는 압곡리, EMD는 봉산면로 다릅니다.
# 48890310 코드는 ad는 권빈리, EMD는 봉산면로 다릅니다.
# 48890310 코드는 ad는 상현리, EMD는 봉산면로 다릅니다.
# 48890310 코드는 ad는 김봉리, EMD는 봉산면로 다릅니다.
# 48890310 코드는 ad는 봉계리, EMD는 봉산면로 다릅니다.
# 48890310 코드는 ad는 송림리, EMD는 봉산면로 다릅니다.
# 48890310 코드는 ad는 계산리, EMD는 봉산면로 다릅니다.
# 48890310 코드는 ad는 고삼리, EMD는 봉산면로 다릅니다.
# 48890310 코드는 ad는 양지리, EMD는 봉산면로 다릅니다.
# 48890310 코드는 ad는 노곡리, EMD는 봉산면로 다릅니다.
# 48890310 코드는 ad는 술곡리, EMD는 봉산면로 다릅니다.
# 48890310 코드는 ad는 도곡리, EMD는 봉산면로 다릅니다.
# 48890320 코드는 ad는 반포리, EMD는 묘산면로 다릅니다.
# 48890320 코드는 ad는 팔심리, EMD는 묘산면로 다릅니다.
# 48890320 코드는 ad는 안성리, EMD는 묘산면로 다릅니다.
# 48890320 코드는 ad는 관기리, EMD는 묘산면로 다릅니다.
# 48890320 코드는 ad는 광산리, EMD는 묘산면로 다릅니다.
# 48890320 코드는 ad는 도옥리, EMD는 묘산면로 다릅니다.
# 48890320 코드는 ad는 산제리, EMD는 묘산면로 다릅니다.
# 48890320 코드는 ad는 가산리, EMD는 묘산면로 다릅니다.
# 48890320 코드는 ad는 화양리, EMD는 묘산면로 다릅니다.
# 48890320 코드는 ad는 거산리, EMD는 묘산면로 다릅니다.
# 48890320 코드는 ad는 봉곡리, EMD는 묘산면로 다릅니다.
# 48890330 코드는 ad는 죽전리, EMD는 가야면로 다릅니다.
# 48890330 코드는 ad는 대전리, EMD는 가야면로 다릅니다.
# 48890330 코드는 ad는 가천리, EMD는 가야면로 다릅니다.
# 48890330 코드는 ad는 구미리, EMD는 가야면로 다릅니다.
# 48890330 코드는 ad는 성기리, EMD는 가야면로 다릅니다.
# 48890330 코드는 ad는 매안리, EMD는 가야면로 다릅니다.
# 48890330 코드는 ad는 매화리, EMD는 가야면로 다릅니다.
# 48890330 코드는 ad는 청현리, EMD는 가야면로 다릅니다.
# 48890330 코드는 ad는 이천리, EMD는 가야면로 다릅니다.
# 48890330 코드는 ad는 사촌리, EMD는 가야면로 다릅니다.
# 48890330 코드는 ad는 황산리, EMD는 가야면로 다릅니다.
# 48890330 코드는 ad는 야천리, EMD는 가야면로 다릅니다.
# 48890330 코드는 ad는 구원리, EMD는 가야면로 다릅니다.
# 48890330 코드는 ad는 치인리, EMD는 가야면로 다릅니다.
# 48890340 코드는 ad는 덕암리, EMD는 야로면로 다릅니다.
# 48890340 코드는 ad는 청계리, EMD는 야로면로 다릅니다.
# 48890340 코드는 ad는 정대리, EMD는 야로면로 다릅니다.
# 48890340 코드는 ad는 월광리, EMD는 야로면로 다릅니다.
# 48890340 코드는 ad는 묵촌리, EMD는 야로면로 다릅니다.
# 48890340 코드는 ad는 구정리, EMD는 야로면로 다릅니다.
# 48890340 코드는 ad는 금평리, EMD는 야로면로 다릅니다.
# 48890340 코드는 ad는 하빈리, EMD는 야로면로 다릅니다.
# 48890340 코드는 ad는 매촌리, EMD는 야로면로 다릅니다.
# 48890340 코드는 ad는 야로리, EMD는 야로면로 다릅니다.
# 48890340 코드는 ad는 하림리, EMD는 야로면로 다릅니다.
# 48890340 코드는 ad는 나대리, EMD는 야로면로 다릅니다.
# 48890350 코드는 ad는 기리, EMD는 율곡면로 다릅니다.
# 48890350 코드는 ad는 내천리, EMD는 율곡면로 다릅니다.
# 48890350 코드는 ad는 두사리, EMD는 율곡면로 다릅니다.
# 48890350 코드는 ad는 갑산리, EMD는 율곡면로 다릅니다.
# 48890350 코드는 ad는 낙민리, EMD는 율곡면로 다릅니다.
# 48890350 코드는 ad는 노양리, EMD는 율곡면로 다릅니다.
# 48890350 코드는 ad는 와리, EMD는 율곡면로 다릅니다.
# 48890350 코드는 ad는 율진리, EMD는 율곡면로 다릅니다.
# 48890350 코드는 ad는 항곡리, EMD는 율곡면로 다릅니다.
# 48890350 코드는 ad는 문림리, EMD는 율곡면로 다릅니다.
# 48890350 코드는 ad는 본천리, EMD는 율곡면로 다릅니다.
# 48890350 코드는 ad는 영전리, EMD는 율곡면로 다릅니다.
# 48890350 코드는 ad는 제내리, EMD는 율곡면로 다릅니다.
# 48890350 코드는 ad는 임북리, EMD는 율곡면로 다릅니다.
# 48890360 코드는 ad는 아막리, EMD는 초계면로 다릅니다.
# 48890360 코드는 ad는 초계리, EMD는 초계면로 다릅니다.
# 48890360 코드는 ad는 중리, EMD는 초계면로 다릅니다.
# 48890360 코드는 ad는 대동리, EMD는 초계면로 다릅니다.
# 48890360 코드는 ad는 상대리, EMD는 초계면로 다릅니다.
# 48890360 코드는 ad는 택리, EMD는 초계면로 다릅니다.
# 48890360 코드는 ad는 원당리, EMD는 초계면로 다릅니다.
# 48890360 코드는 ad는 관평리, EMD는 초계면로 다릅니다.
# 48890360 코드는 ad는 대평리, EMD는 초계면로 다릅니다.
# 48890360 코드는 ad는 유하리, EMD는 초계면로 다릅니다.
# 48890360 코드는 ad는 신촌리, EMD는 초계면로 다릅니다.
# 48890370 코드는 ad는 상신리, EMD는 쌍책면로 다릅니다.
# 48890370 코드는 ad는 하신리, EMD는 쌍책면로 다릅니다.
# 48890370 코드는 ad는 건태리, EMD는 쌍책면로 다릅니다.
# 48890370 코드는 ad는 사양리, EMD는 쌍책면로 다릅니다.
# 48890370 코드는 ad는 덕봉리, EMD는 쌍책면로 다릅니다.
# 48890370 코드는 ad는 상포리, EMD는 쌍책면로 다릅니다.
# 48890370 코드는 ad는 성산리, EMD는 쌍책면로 다릅니다.
# 48890370 코드는 ad는 진정리, EMD는 쌍책면로 다릅니다.
# 48890370 코드는 ad는 다라리, EMD는 쌍책면로 다릅니다.
# 48890370 코드는 ad는 오서리, EMD는 쌍책면로 다릅니다.
# 48890380 코드는 ad는 포두리, EMD는 덕곡면로 다릅니다.
# 48890380 코드는 ad는 장리, EMD는 덕곡면로 다릅니다.
# 48890380 코드는 ad는 병배리, EMD는 덕곡면로 다릅니다.
# 48890380 코드는 ad는 학리, EMD는 덕곡면로 다릅니다.
# 48890380 코드는 ad는 율지리, EMD는 덕곡면로 다릅니다.
# 48890380 코드는 ad는 율원리, EMD는 덕곡면로 다릅니다.
# 48890380 코드는 ad는 본곡리, EMD는 덕곡면로 다릅니다.
# 48890390 코드는 ad는 적포리, EMD는 청덕면로 다릅니다.
# 48890390 코드는 ad는 두곡리, EMD는 청덕면로 다릅니다.
# 48890390 코드는 ad는 대부리, EMD는 청덕면로 다릅니다.
# 48890390 코드는 ad는 앙진리, EMD는 청덕면로 다릅니다.
# 48890390 코드는 ad는 모리, EMD는 청덕면로 다릅니다.
# 48890390 코드는 ad는 미곡리, EMD는 청덕면로 다릅니다.
# 48890390 코드는 ad는 성태리, EMD는 청덕면로 다릅니다.
# 48890390 코드는 ad는 삼학리, EMD는 청덕면로 다릅니다.
# 48890390 코드는 ad는 소례리, EMD는 청덕면로 다릅니다.
# 48890390 코드는 ad는 운봉리, EMD는 청덕면로 다릅니다.
# 48890390 코드는 ad는 초곡리, EMD는 청덕면로 다릅니다.
# 48890390 코드는 ad는 가현리, EMD는 청덕면로 다릅니다.
# 48890400 코드는 ad는 죽고리, EMD는 적중면로 다릅니다.
# 48890400 코드는 ad는 황정리, EMD는 적중면로 다릅니다.
# 48890400 코드는 ad는 정토리, EMD는 적중면로 다릅니다.
# 48890400 코드는 ad는 옥두리, EMD는 적중면로 다릅니다.
# 48890400 코드는 ad는 부수리, EMD는 적중면로 다릅니다.
# 48890400 코드는 ad는 누하리, EMD는 적중면로 다릅니다.
# 48890400 코드는 ad는 상부리, EMD는 적중면로 다릅니다.
# 48890400 코드는 ad는 양림리, EMD는 적중면로 다릅니다.
# 48890400 코드는 ad는 두방리, EMD는 적중면로 다릅니다.
# 48890410 코드는 ad는 정양리, EMD는 대양면로 다릅니다.
# 48890410 코드는 ad는 아천리, EMD는 대양면로 다릅니다.
# 48890410 코드는 ad는 대목리, EMD는 대양면로 다릅니다.
# 48890410 코드는 ad는 무곡리, EMD는 대양면로 다릅니다.
# 48890410 코드는 ad는 덕정리, EMD는 대양면로 다릅니다.
# 48890410 코드는 ad는 도리, EMD는 대양면로 다릅니다.
# 48890410 코드는 ad는 함지리, EMD는 대양면로 다릅니다.
# 48890410 코드는 ad는 양산리, EMD는 대양면로 다릅니다.
# 48890410 코드는 ad는 안금리, EMD는 대양면로 다릅니다.
# 48890410 코드는 ad는 백암리, EMD는 대양면로 다릅니다.
# 48890410 코드는 ad는 오산리, EMD는 대양면로 다릅니다.
# 48890420 코드는 ad는 대곡리, EMD는 쌍백면로 다릅니다.
# 48890420 코드는 ad는 육리, EMD는 쌍백면로 다릅니다.
# 48890420 코드는 ad는 평구리, EMD는 쌍백면로 다릅니다.
# 48890420 코드는 ad는 평지리, EMD는 쌍백면로 다릅니다.
# 48890420 코드는 ad는 안계리, EMD는 쌍백면로 다릅니다.
# 48890420 코드는 ad는 대현리, EMD는 쌍백면로 다릅니다.
# 48890420 코드는 ad는 외초리, EMD는 쌍백면로 다릅니다.
# 48890420 코드는 ad는 장전리, EMD는 쌍백면로 다릅니다.
# 48890420 코드는 ad는 운곡리, EMD는 쌍백면로 다릅니다.
# 48890420 코드는 ad는 백역리, EMD는 쌍백면로 다릅니다.
# 48890420 코드는 ad는 하신리, EMD는 쌍백면로 다릅니다.
# 48890420 코드는 ad는 삼리, EMD는 쌍백면로 다릅니다.
# 48890420 코드는 ad는 죽전리, EMD는 쌍백면로 다릅니다.
# 48890430 코드는 ad는 동리, EMD는 삼가면로 다릅니다.
# 48890430 코드는 ad는 용흥리, EMD는 삼가면로 다릅니다.
# 48890430 코드는 ad는 외토리, EMD는 삼가면로 다릅니다.
# 48890430 코드는 ad는 일부리, EMD는 삼가면로 다릅니다.
# 48890430 코드는 ad는 어전리, EMD는 삼가면로 다릅니다.
# 48890430 코드는 ad는 양전리, EMD는 삼가면로 다릅니다.
# 48890430 코드는 ad는 금리, EMD는 삼가면로 다릅니다.
# 48890430 코드는 ad는 두모리, EMD는 삼가면로 다릅니다.
# 48890430 코드는 ad는 소오리, EMD는 삼가면로 다릅니다.
# 48890430 코드는 ad는 하판리, EMD는 삼가면로 다릅니다.
# 48890430 코드는 ad는 문송리, EMD는 삼가면로 다릅니다.
# 48890430 코드는 ad는 덕진리, EMD는 삼가면로 다릅니다.
# 48890430 코드는 ad는 학리, EMD는 삼가면로 다릅니다.
# 48890440 코드는 ad는 월계리, EMD는 가회면로 다릅니다.
# 48890440 코드는 ad는 도탄리, EMD는 가회면로 다릅니다.
# 48890440 코드는 ad는 오도리, EMD는 가회면로 다릅니다.
# 48890440 코드는 ad는 둔내리, EMD는 가회면로 다릅니다.
# 48890440 코드는 ad는 중촌리, EMD는 가회면로 다릅니다.
# 48890440 코드는 ad는 덕촌리, EMD는 가회면로 다릅니다.
# 48890440 코드는 ad는 함방리, EMD는 가회면로 다릅니다.
# 48890440 코드는 ad는 장대리, EMD는 가회면로 다릅니다.
# 48890440 코드는 ad는 외사리, EMD는 가회면로 다릅니다.
# 48890450 코드는 ad는 상천리, EMD는 대병면로 다릅니다.
# 48890450 코드는 ad는 역평리, EMD는 대병면로 다릅니다.
# 48890450 코드는 ad는 회양리, EMD는 대병면로 다릅니다.
# 48890450 코드는 ad는 유전리, EMD는 대병면로 다릅니다.
# 48890450 코드는 ad는 양리, EMD는 대병면로 다릅니다.
# 48890450 코드는 ad는 하금리, EMD는 대병면로 다릅니다.
# 48890450 코드는 ad는 장단리, EMD는 대병면로 다릅니다.
# 48890450 코드는 ad는 대지리, EMD는 대병면로 다릅니다.
# 48890450 코드는 ad는 성리, EMD는 대병면로 다릅니다.
# 48890460 코드는 ad는 공암리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 황계리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 장전리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 노리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 평산리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 손목리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 팔산리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 용지리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 성산리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 월평리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 방곡리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 고품리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 봉기리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 우곡리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 죽죽리, EMD는 용주면로 다릅니다.
# 48890460 코드는 ad는 가호리, EMD는 용주면로 다릅니다.
# 50110250 코드는 ad는 귀덕리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 수원리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 대림리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 한림리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 금악리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 동명리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 명월리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 옹포리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 상대리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 상명리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 협재리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 월령리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 금능리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 월림리, EMD는 한림읍로 다릅니다.
# 50110250 코드는 ad는 한수리, EMD는 한림읍로 다릅니다.
# 50110253 코드는 ad는 용흥리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 중엄리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 광령리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 상귀리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 구엄리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 수산리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 신엄리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 장전리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 소길리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 고성리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 하가리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 상가리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 고내리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 애월리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 납읍리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 어음리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 곽지리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 금성리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 봉성리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 하귀1리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 하귀2리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 유수암리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 광령1리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 광령2리, EMD는 애월읍로 다릅니다.
# 50110253 코드는 ad는 광령3리, EMD는 애월읍로 다릅니다.
# 50110256 코드는 ad는 동복리, EMD는 구좌읍로 다릅니다.
# 50110256 코드는 ad는 덕천리, EMD는 구좌읍로 다릅니다.
# 50110256 코드는 ad는 송당리, EMD는 구좌읍로 다릅니다.
# 50110256 코드는 ad는 월정리, EMD는 구좌읍로 다릅니다.
# 50110256 코드는 ad는 행원리, EMD는 구좌읍로 다릅니다.
# 50110256 코드는 ad는 세화리, EMD는 구좌읍로 다릅니다.
# 50110256 코드는 ad는 상도리, EMD는 구좌읍로 다릅니다.
# 50110256 코드는 ad는 한동리, EMD는 구좌읍로 다릅니다.
# 50110256 코드는 ad는 하도리, EMD는 구좌읍로 다릅니다.
# 50110256 코드는 ad는 종달리, EMD는 구좌읍로 다릅니다.
# 50110256 코드는 ad는 평대리, EMD는 구좌읍로 다릅니다.
# 50110256 코드는 ad는 김녕리, EMD는 구좌읍로 다릅니다.
# 50110259 코드는 ad는 신촌리, EMD는 조천읍로 다릅니다.
# 50110259 코드는 ad는 와흘리, EMD는 조천읍로 다릅니다.
# 50110259 코드는 ad는 조천리, EMD는 조천읍로 다릅니다.
# 50110259 코드는 ad는 함덕리, EMD는 조천읍로 다릅니다.
# 50110259 코드는 ad는 신흥리, EMD는 조천읍로 다릅니다.
# 50110259 코드는 ad는 대흘리, EMD는 조천읍로 다릅니다.
# 50110259 코드는 ad는 북촌리, EMD는 조천읍로 다릅니다.
# 50110259 코드는 ad는 와산리, EMD는 조천읍로 다릅니다.
# 50110259 코드는 ad는 교래리, EMD는 조천읍로 다릅니다.
# 50110259 코드는 ad는 선흘리, EMD는 조천읍로 다릅니다.
# 50110310 코드는 ad는 청수리, EMD는 한경면로 다릅니다.
# 50110310 코드는 ad는 용수리, EMD는 한경면로 다릅니다.
# 50110310 코드는 ad는 고산리, EMD는 한경면로 다릅니다.
# 50110310 코드는 ad는 판포리, EMD는 한경면로 다릅니다.
# 50110310 코드는 ad는 금등리, EMD는 한경면로 다릅니다.
# 50110310 코드는 ad는 조수리, EMD는 한경면로 다릅니다.
# 50110310 코드는 ad는 두모리, EMD는 한경면로 다릅니다.
# 50110310 코드는 ad는 신창리, EMD는 한경면로 다릅니다.
# 50110310 코드는 ad는 낙천리, EMD는 한경면로 다릅니다.
# 50110310 코드는 ad는 저지리, EMD는 한경면로 다릅니다.
# 50110310 코드는 ad는 산양리, EMD는 한경면로 다릅니다.
# 50110310 코드는 ad는 한원리, EMD는 한경면로 다릅니다.
# 50110310 코드는 ad는 용당리, EMD는 한경면로 다릅니다.
# 50110320 코드는 ad는 대서리, EMD는 추자면로 다릅니다.
# 50110320 코드는 ad는 영흥리, EMD는 추자면로 다릅니다.
# 50110320 코드는 ad는 묵리, EMD는 추자면로 다릅니다.
# 50110320 코드는 ad는 예초리, EMD는 추자면로 다릅니다.
# 50110320 코드는 ad는 신양리, EMD는 추자면로 다릅니다.
# 50110330 코드는 ad는 연평리, EMD는 우도면로 다릅니다.
# 50110330 코드는 ad는 서광리, EMD는 우도면로 다릅니다.
# 50110330 코드는 ad는 천진리, EMD는 우도면로 다릅니다.
# 50110330 코드는 ad는 조일리, EMD는 우도면로 다릅니다.
# 50110330 코드는 ad는 오봉리, EMD는 우도면로 다릅니다.
# 50130250 코드는 ad는 상모리, EMD는 대정읍로 다릅니다.
# 50130250 코드는 ad는 하모리, EMD는 대정읍로 다릅니다.
# 50130250 코드는 ad는 안성리, EMD는 대정읍로 다릅니다.
# 50130250 코드는 ad는 인성리, EMD는 대정읍로 다릅니다.
# 50130250 코드는 ad는 일과리, EMD는 대정읍로 다릅니다.
# 50130250 코드는 ad는 가파리, EMD는 대정읍로 다릅니다.
# 50130250 코드는 ad는 신평리, EMD는 대정읍로 다릅니다.
# 50130250 코드는 ad는 동일리, EMD는 대정읍로 다릅니다.
# 50130250 코드는 ad는 보성리, EMD는 대정읍로 다릅니다.
# 50130250 코드는 ad는 구억리, EMD는 대정읍로 다릅니다.
# 50130250 코드는 ad는 무릉리, EMD는 대정읍로 다릅니다.
# 50130250 코드는 ad는 영락리, EMD는 대정읍로 다릅니다.
# 50130250 코드는 ad는 신도리, EMD는 대정읍로 다릅니다.
# 50130253 코드는 ad는 남원리, EMD는 남원읍로 다릅니다.
# 50130253 코드는 ad는 태흥리, EMD는 남원읍로 다릅니다.
# 50130253 코드는 ad는 한남리, EMD는 남원읍로 다릅니다.
# 50130253 코드는 ad는 수망리, EMD는 남원읍로 다릅니다.
# 50130253 코드는 ad는 의귀리, EMD는 남원읍로 다릅니다.
# 50130253 코드는 ad는 신흥리, EMD는 남원읍로 다릅니다.
# 50130253 코드는 ad는 위미리, EMD는 남원읍로 다릅니다.
# 50130253 코드는 ad는 하례리, EMD는 남원읍로 다릅니다.
# 50130253 코드는 ad는 신례리, EMD는 남원읍로 다릅니다.
# 50130259 코드는 ad는 성산리, EMD는 성산읍로 다릅니다.
# 50130259 코드는 ad는 오조리, EMD는 성산읍로 다릅니다.
# 50130259 코드는 ad는 시흥리, EMD는 성산읍로 다릅니다.
# 50130259 코드는 ad는 고성리, EMD는 성산읍로 다릅니다.
# 50130259 코드는 ad는 수산리, EMD는 성산읍로 다릅니다.
# 50130259 코드는 ad는 온평리, EMD는 성산읍로 다릅니다.
# 50130259 코드는 ad는 신산리, EMD는 성산읍로 다릅니다.
# 50130259 코드는 ad는 삼달리, EMD는 성산읍로 다릅니다.
# 50130259 코드는 ad는 신풍리, EMD는 성산읍로 다릅니다.
# 50130259 코드는 ad는 신천리, EMD는 성산읍로 다릅니다.
# 50130259 코드는 ad는 난산리, EMD는 성산읍로 다릅니다.
# 50130310 코드는 ad는 대평리, EMD는 안덕면로 다릅니다.
# 50130310 코드는 ad는 화순리, EMD는 안덕면로 다릅니다.
# 50130310 코드는 ad는 창천리, EMD는 안덕면로 다릅니다.
# 50130310 코드는 ad는 감산리, EMD는 안덕면로 다릅니다.
# 50130310 코드는 ad는 상창리, EMD는 안덕면로 다릅니다.
# 50130310 코드는 ad는 사계리, EMD는 안덕면로 다릅니다.
# 50130310 코드는 ad는 덕수리, EMD는 안덕면로 다릅니다.
# 50130310 코드는 ad는 서광리, EMD는 안덕면로 다릅니다.
# 50130310 코드는 ad는 동광리, EMD는 안덕면로 다릅니다.
# 50130310 코드는 ad는 광평리, EMD는 안덕면로 다릅니다.
# 50130310 코드는 ad는 상천리, EMD는 안덕면로 다릅니다.
# 50130320 코드는 ad는 표선리, EMD는 표선면로 다릅니다.
# 50130320 코드는 ad는 하천리, EMD는 표선면로 다릅니다.
# 50130320 코드는 ad는 성읍리, EMD는 표선면로 다릅니다.
# 50130320 코드는 ad는 가시리, EMD는 표선면로 다릅니다.
# 50130320 코드는 ad는 세화리, EMD는 표선면로 다릅니다.
# 50130320 코드는 ad는 토산리, EMD는 표선면로 다릅니다.

# %%
ad_area = pd.merge(adCode_EMD, emd_area, on='EMD_CD', how= 'inner')
ad_area.head()
# Out:
#       시도  시군구  행정구역명 행정동(행정기관명)  법정동   행정구역코드    EMD_CD       EMD_ENG_NM  \
# 0  서울특별시  종로구  청운효자동      청운효자동  청운동  1101072  11110101    Cheongun-dong
# 1  서울특별시  종로구  청운효자동      청운효자동  신교동  1101072  11110102      Singyo-dong
# 2  서울특별시  종로구  청운효자동      청운효자동  궁정동  1101072  11110103   Gungjeong-dong
# 3  서울특별시  종로구  청운효자동      청운효자동  효자동  1101072  11110104       Hyoja-dong
# 4  서울특별시  종로구  청운효자동      청운효자동  창성동  1101072  11110105  Changseong-dong
#
#   EMD_KOR_NM                                           geometry
# 0        청운동  POLYGON ((953700.022 1954605.065, 953693.871 1...
# 1        신교동  POLYGON ((953233.465 1953996.984, 953235.183 1...
# 2        궁정동  POLYGON ((953560.228 1954257.466, 953561.190 1...
# 3        효자동  POLYGON ((953519.843 1953890.785, 953518.489 1...
# 4        창성동  POLYGON ((953516.123 1953734.362, 953516.526 1...

# %%
ad_area.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21327 entries, 0 to 21326
# Data columns (total 10 columns):
# 시도            21327 non-null object
# 시군구           21327 non-null object
# 행정구역명         21327 non-null object
# 행정동(행정기관명)    21327 non-null object
# 법정동           21327 non-null object
# 행정구역코드        21327 non-null object
# EMD_CD        21327 non-null object
# EMD_ENG_NM    21327 non-null object
# EMD_KOR_NM    21327 non-null object
# geometry      21327 non-null geometry
# dtypes: geometry(1), object(9)
# memory usage: 1.8+ MB

# %%
ad_area_gdf = gpd.GeoDataFrame(ad_area, geometry=ad_area['geometry'])
ad_area_gdf.head()
# Out:
#       시도  시군구  행정구역명 행정동(행정기관명)  법정동   행정구역코드    EMD_CD       EMD_ENG_NM  \
# 0  서울특별시  종로구  청운효자동      청운효자동  청운동  1101072  11110101    Cheongun-dong
# 1  서울특별시  종로구  청운효자동      청운효자동  신교동  1101072  11110102      Singyo-dong
# 2  서울특별시  종로구  청운효자동      청운효자동  궁정동  1101072  11110103   Gungjeong-dong
# 3  서울특별시  종로구  청운효자동      청운효자동  효자동  1101072  11110104       Hyoja-dong
# 4  서울특별시  종로구  청운효자동      청운효자동  창성동  1101072  11110105  Changseong-dong
#
#   EMD_KOR_NM                                           geometry
# 0        청운동  POLYGON ((953700.022 1954605.065, 953693.871 1...
# 1        신교동  POLYGON ((953233.465 1953996.984, 953235.183 1...
# 2        궁정동  POLYGON ((953560.228 1954257.466, 953561.190 1...
# 3        효자동  POLYGON ((953519.843 1953890.785, 953518.489 1...
# 4        창성동  POLYGON ((953516.123 1953734.362, 953516.526 1...

# %%
ad_area_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 21327 entries, 0 to 21326
# Data columns (total 10 columns):
# 시도            21327 non-null object
# 시군구           21327 non-null object
# 행정구역명         21327 non-null object
# 행정동(행정기관명)    21327 non-null object
# 법정동           21327 non-null object
# 행정구역코드        21327 non-null object
# EMD_CD        21327 non-null object
# EMD_ENG_NM    21327 non-null object
# EMD_KOR_NM    21327 non-null object
# geometry      21327 non-null geometry
# dtypes: geometry(1), object(9)
# memory usage: 1.8+ MB

# %%
ad_area_gdf.plot(column='행정구역명',figsize=(25,25))

# %%
seoul_ad_area = ad_area_gdf[ad_area_gdf['시도']=='서울특별시']
seoul_ad_area.plot(column='행정동(행정기관명)',figsize=(25,25),cmap='cividis')

# %%
gyeonggi_ad_area = ad_area_gdf[ad_area_gdf['시도']=='경기도']
gyeonggi_ad_area.plot(column='행정동(행정기관명)',figsize=(25,25),cmap='cividis')

# %%
gwanggyo_ad_area = ad_area_gdf[ad_area_gdf['행정구역명'].str.contains('광교')]
gwanggyo_ad_area.head(10)
# Out:
#        시도      시군구 행정구역명 행정동(행정기관명)  법정동   행정구역코드    EMD_CD EMD_ENG_NM  \
# 2757  경기도  수원시 영통구  광교1동       광교1동  이의동  3101462  41117103   Iui-dong
# 2758  경기도  수원시 영통구  광교2동       광교2동   하동  3101463  41117104    Ha-dong
#
#      EMD_KOR_NM                                           geometry
# 2757        이의동  POLYGON ((959903.465 1924278.680, 959905.829 1...
# 2758         하동  POLYGON ((963418.474 1922209.041, 963446.058 1...

# %%
gwanggyo_ad_area.plot(column='행정동(행정기관명)',figsize=(25,25),cmap='cividis')

# %%
dongtan_ad_area = ad_area_gdf[ad_area_gdf['행정구역명'].str.contains('동탄')]
dongtan_ad_area.head(10)
# Out:
#        시도  시군구 행정구역명 행정동(행정기관명)  법정동   행정구역코드    EMD_CD       EMD_ENG_NM  \
# 4323  경기도  화성시  동탄3동       동탄3동   능동  3124062  41590118       Neung-dong
# 4334  경기도  화성시  동탄1동       동탄1동  반송동  3124061  41590127     Bansong-dong
# 4335  경기도  화성시  동탄2동       동탄2동  반송동  3124060  41590127     Bansong-dong
# 4336  경기도  화성시  동탄1동       동탄1동  석우동  3124061  41590128       Seogu-dong
# 4337  경기도  화성시  동탄4동       동탄4동  청계동  3124064  41590130   Cheonggye-dong
# 4338  경기도  화성시  동탄5동       동탄5동  영천동  3124065  41590131  Yeongcheon-dong
# 4339  경기도  화성시  동탄5동       동탄5동   중동  3124065  41590132        Jung-dong
# 4340  경기도  화성시  동탄7동       동탄7동   신동  3124069  41590133         Sin-dong
# 4341  경기도  화성시  동탄7동       동탄7동   목동  3124069  41590134         Mok-dong
# 4342  경기도  화성시  동탄7동       동탄7동  산척동  3124069  41590135    Sancheok-dong
#
#      EMD_KOR_NM                                           geometry
# 4323         능동  POLYGON ((960906.208 1911317.755, 960906.550 1...
# 4334        반송동  POLYGON ((962985.905 1909578.215, 962977.415 1...
# 4335        반송동  POLYGON ((962985.905 1909578.215, 962977.415 1...
# 4336        석우동  POLYGON ((963445.475 1913165.328, 963455.050 1...
# 4337        청계동  POLYGON ((967166.855 1911441.665, 967196.158 1...
# 4338        영천동  POLYGON ((963247.538 1911847.557, 963250.648 1...
# 4339         중동  POLYGON ((969025.009 1913502.752, 969036.227 1...
# 4340         신동  POLYGON ((969142.006 1911124.678, 969144.349 1...
# 4341         목동  POLYGON ((967296.524 1910830.035, 967296.415 1...
# 4342        산척동  POLYGON ((965695.458 1909037.017, 965713.498 1...

# %%
plt.rc('font', family='NanumGothic')
dongtan_ad_area.plot(column='행정동(행정기관명)',figsize=(25,25),cmap='cividis',categorical=True,legend=True)
